# %%
import json
import re
from dataclasses import dataclass, field
from typing import List

# %%
@dataclass
class Followers:
    key: str
    followers: list[str] = field(default_factory=list)

f = open('followers_US.json', "r")

data = json.loads(f.read())

# print(json.dumps(data, indent = 4, sort_keys = True))

def split_html(content):
    return re.split(r'(<[^>]+>)', content)

def get_usernames(content):
    pattern = r'@\w+'
    return re.findall(pattern, content)

follower_list = []

for key, value in data.items():
    follower_data = Followers(key=key)
    for item in value:
        separated_html = split_html(item)
        for part in separated_html:
            if part.strip() and not re.match(r'</[^>]+>', part) and '@' in part:
                usernames = get_usernames(part)
                for username in usernames:
                    if username not in follower_data.followers:
                        follower_data.followers.extend(usernames)
    follower_list.append(follower_data)

for follower in follower_list:
    print(f'Key: {follower.key}')
    print(f'Followers:', follower.followers)
    print('----')

with open('followers_US.txt', 'a') as file:
    for follower in follower_list:
        file.write(f'Account:{follower.key}\n')
        file.write('Followers:\n')
        for username in follower.followers:
            file.write(f'{username}\n')
        file.write('----\n')
    
f.close()
# Out:
# Key: PatTheSocialist
# Followers: ['@PatTheSocialist', '@JakedChinatown', '@feral_leafeon', '@JulieMorency', '@FlaDems', '@Organize2020FL', '@make_mine_marx', '@KeithThompson1', '@RuudMfSinner', '@Vinnie958269385', '@DrGorfinkel', '@CBCRadio', '@GlobalNewsTo', '@ZoomerMedia', '@TorontoStar', '@dririsgorfinkel', '@megpillow', '@rgay', '@AlyssaJennette', '@lindsayballant', '@newrepublic', '@thebafflermag', '@JeanGreige', '@thiswithcoffee', '@MaxMicallef', '@Avadi_art', '@meteor_hammer', '@TroubleAt_Mill']
# ----
# Key: SabbySabs2
# Followers: ['@SabbySabs2', '@qbounti', '@DoniTheMisfit', '@Abandonbiden24', '@gmail', '@equalityAlec', '@CivRightsCorps', '@VanessaBeeley', '@MrShermichael', '@CNN', '@gunsouttv', '@TheRealCzezre', '@ActiveMeasures8', '@KitKlarenberg', '@RealAlexRubi', '@blackleftis', '@sneedlaw', '@ToddforFL4', '@legislationpage', '@SeymourMHersh', '@asatarbair', '@threadsdrbair', '@Headline_Beyond']
# ----
# Key: TristanSnell
# Followers: ['@TristanSnell', '@IvarFodnes', '@ZVeselich', '@maplescribe', '@CJHatterz', '@Eco_Evo_Austin', '@michigantech', '@FinlandiaU', '@dawnheartswomen', '@cottylad5656', '@Decsbarmyarmy', '@mojadita_xoxo', '@Be_inTIMidated', '@waffleupapollo', '@DoctoraKaro', '@srcimaging', '@daBombcsmith', '@WellsWarning', '@PSUmeteo', '@MaxBuckley13', '@khwass20', '@Ilovepeeing1']
# ----
# Key: BernardKerik
# Followers: ['@BernardKerik', '@EndWokeness', '@sav_says_', '@TPUSA', '@TPostMillennial', '@wildbarestepf', '@wildbaremuse', '@Corey_Comper', '@realErikDPrince', '@HaysSheriff', '@Highway_30', '@JDunlap1974', '@WillABarclay', '@TulsaKing', '@TheSlyStallone', '@ParamountPlus', '@foxxsgt1', '@TCNetwork', '@NYSYRWomen', '@NYRACC', '@TMZCopGuy', '@KeeleyFox29']
# ----
# Key: spann
# Followers: ['@spann', '@aldotcom', '@Greg_Byrne', '@UofAlabama', '@abc3340', '@jimdunaway', '@NextRoundLive', '@DisruptTheMedia', '@CStewartSports', '@RyanBrownLive', '@nextroundlive', '@disruptthemedia', '@NWSBirmingham', '@bigvox', '@WxLiz']
# ----
# Key: jeff_poor
# Followers: ['@jeff_poor', '@1819News', '@AuburnFootball', '@willainsworthAL', '@TheDaleJackson', '@yhn', '@SenTuberville', '@coachbrucepearl', '@toddcstacy', '@CapitolJournal', '@APTV', '@SenKatieBritt']
# ----
# Key: DavidAFrench
# Followers: ['@DavidAFrench', '@JonahDispatch', '@TheDispatch', '@charlescwcooke', '@philvischer', '@KaitlynSchiess', '@DukeDivinity', '@dallasseminary', '@HolyPostPodcast', '@SonnyBunch', '@SubBeacon', '@EsotericCD', '@Political_Beats', '@NRO', '@scottlincicome', '@CatoInstitute', '@DukeLaw', '@Rangers', '@bethallisonbarr', '@BaylorHistory', '@boydellbrewer', '@Baylor_Press', '@BrazosPress', '@KSPrior', '@karenswallowp']
# ----
# Key: NancyAFrench
# Followers: ['@NancyAFrench', '@SpikingTDs', '@RClaussen2', '@ReaganCaucus', '@pages_and', '@carrieeorton', '@childrensmuseum', '@NavyPier', '@RevJenButler', '@sleepnomorenyc', '@Gp021970', '@salgentile', '@latenightseth', '@ICSmartpeople', '@debbieharrislon', '@Douglas_Wolf_', '@CaseyonEarth', '@carmenjoyimes']
# ----
# Key: BillOReilly
# Followers: ['@BillOReilly', '@TomFitton', '@TomiLahren', '@tlisfearless', '@Outkick', '@foxnews', '@foxnewsradio', '@seanhannity', '@MonicaCrowley', '@BuckSexton', '@clayandbuck', '@iheartradio', '@kimguilfoyle', '@IngrahamAngle', '@FoxNews', '@glennbeck', '@MariaBartiromo', '@MorningsMaria', '@FoxBusiness', '@SundayFutures']
# ----
# Key: Jaybefaunt
# Followers: ['@Jaybefaunt', '@SocialistMMA', '@RevBlackNetwork', '@SabbySabs2', '@ProudSocialist', '@AmpedUpPodcast', '@SarcasmStardust', '@action_4assange', '@anthonyzenkus', '@ComptonMadeMe', '@RBNInlandEmpire', '@MutualAid4ever', '@joeywreck', '@ThiaBallerina', '@PrimoRadical']
# ----
# Key: donwinslow
# Followers: ['@donwinslow', '@mmpadellan', '@ReallyAmerican1', '@CalltoActivism', '@joncoopertweets', '@robreiner', '@MeidasTouch', '@TheRickWilson', '@RepAdamSchiff', '@MaryLTrump', '@marceelias', '@DemocracyDocket', '@EliasLawGroup']
# ----
# Key: KyleClark
# Followers: ['@KyleClark', '@GovofCO', '@9NEWS', '@SteveStaeger', '@9News', '@9news', '@cprwarner', '@ColoradoMatters', '@oddryhepburn', '@chrisvanderveen', '@NPPA', '@DenverChannel', '@denver7', '@jim_benemann', '@NWSBoulder', '@jaredpolis']
# ----
# Key: BobMurphyEcon
# Followers: ['@BobMurphyEcon', '@LPMisesCaucus', '@ThomasEWoods', '@scotthortonshow', '@FreemansMind96', '@LibertyLockPod', '@angela4LNCChair', '@lpnational', '@jeffdeist', '@Monetary_Metals', '@mises', '@ronpaul', '@PerBylund', '@okstate', '@Ratio_Institute', '@RonPaulInstitut', '@jeremykauffman']
# ----
# Key: ThomasEWoods
# Followers: ['@ThomasEWoods', '@ComicDaveSmith', '@gmail', '@LPMisesCaucus', '@scotthortonshow', '@FreemansMind96', '@LibertyLockPod', '@angela4LNCChair', '@lpnational', '@BobMurphyEcon', '@infineogroup', '@LPNH', '@ShaneTHazel', '@jeffdeist', '@Monetary_Metals', '@mises', '@ronpaul']
# ----
# Key: bshelburne
# Followers: ['@bshelburne', '@Josh_Moon', '@randallwoodfin', '@WarOnDumb', '@aldotcom', '@glennEmartin', '@JohnArchibald', '@Niemanfdn', '@RepTerriSewell', '@DyjuanTatro', '@BPIBard', '@thefortunesoc', '@cellsecrets', '@DavidLeegarlock', '@eji_org', '@EasternU', '@MarshallProj', '@Mitigation_Hope', '@WBRCnews', '@RDunhamDP', '@PhillipsBlackPr', '@TempleLaw', '@Penn', '@GeorgetownLaw', '@DPInfoCtr', '@paroleproject', '@JoshuaBHoe', '@TabithaK', '@RepEngland70', '@leahanelson', '@AlaAppleseed']
# ----
# Key: PatrickSvitek
# Followers: ['@PatrickSvitek', '@evanasmith', '@emcollective', '@theatlantic', '@thelbjschool', '@overheardpbs', '@uvademocracy', '@austinfilm', '@lbjfoundation', '@texastribune', '@texasmonthly', '@wilco', '@DadePhelan', '@DadePhelanTxESP', '@GeneforTexas', '@MiyaShay', '@evan7257', '@longhornderek', '@leachfortexas', '@BriscoeCain', '@houstonchron', '@nytimes', '@CeliaIsrael', '@CarolineForTX']
# ----
# Key: evanasmith
# Followers: ['@evanasmith', '@PatrickSvitek', '@WashingtonPost', '@TexasTribune', '@HoustonChron', '@washpost', '@DadePhelan', '@DadePhelanTxESP', '@evan7257', '@mattlargey', '@KUT', '@NPR', '@SaltInstitute', '@DonnaHowardTX', '@KirkPWatson', '@CeliaIsrael', '@longhornderek', '@RepLloydDoggett']
# ----
# Key: MsLaToshaBrown
# Followers: ['@MsLaToshaBrown', '@nhannahjones', '@nytmag', '@IBWellsSociety', '@c4jdhowardu', '@howardu', '@tiffanydcross', '@TiffanyDCross', '@rolandsmartin', '@Bakari_Sellers', '@CNN', '@StromLaw', '@CapehartJ', '@PostLive', '@WeekendCapehart', '@NewsHour', '@SymoneDSanders', '@theweekendmsnbc', '@BlackWomenViews', '@ReecieColbert', '@SiriusXM', '@amitrippingame', '@malcolmkenyatta', '@POTUS', '@drmattkenyatta', '@mayawiley', '@civilrightsorg', '@msnbc', '@Maya4CivilRights']
# ----
# Key: TomFitton
# Followers: ['@TomFitton', '@Jim_Jordan', '@JudiciaryGOP', '@Weaponization', '@DineshDSouza', '@dbongino', '@laurenboebert', '@RepMTG', '@TheLeoTerrell', '@foxnews', '@bennyjohnson', '@marklevinshow', '@mattgaetz']
# ----
# Key: BarbMcQuade
# Followers: ['@BarbMcQuade', '@JoyceWhiteVance', '@UALawSchool', '@MSNBC', '@NBCNews', '@TheRickWilson', '@RepAdamSchiff', '@tribelaw', '@gtconway3d', '@PsychoPAC24', '@chkbal', '@TheAtlantic', '@MuellerSheWrote', '@RepSwalwell', '@HouseJudiciary', '@HomelandDems', '@BeschlossDC', '@PBS', '@beschlossdc17', '@marceelias', '@DemocracyDocket', '@EliasLawGroup']
# ----
# Key: JohnArchibald
# Followers: ['@JohnArchibald', '@Josh_Moon', '@WarOnDumb', '@aldotcom', '@randallwoodfin', '@bshelburne', '@RepTerriSewell', '@jimdunaway', '@NextRoundLive', '@DisruptTheMedia', '@JoeGoodmanJr', '@ALdotcom', '@UAB_FB']
# ----
# Key: brad_polumbo
# Followers: ['@brad_polumbo', '@HannahDCox', '@whitecoatwaste', '@neoavatara', '@feeonline', '@chadfelixg', '@TwitchyTeam', '@RedState', '@FDRLST', '@ToddHagopian', '@AP4Liberty', '@reason', '@ReasonFdn', '@robbysoave', '@RisingTheHill', '@ChaseForLiberty']
# ----
# Key: natsechobbyist
# Followers: ['@natsechobbyist', '@MuellerSheWrote', '@RonFilipkowski', '@TheRickWilson', '@RepSwalwell', '@HouseJudiciary', '@HomelandDems', '@marceelias', '@DemocracyDocket', '@EliasLawGroup', '@AVindman', '@votevets', '@JoyceWhiteVance', '@UALawSchool', '@MSNBC', '@NBCNews', '@duty2warn', '@tribelaw']
# ----
# Key: jimmy_dore
# Followers: ['@jimmy_dore', '@aaronjmate', '@TheGrayzoneNews', '@UsefulIdiotpod', '@protonmail', '@caitoz', '@MaxBlumenthal', '@mtracey', '@ComicDaveSmith', '@gmail', '@blackintheempir', '@jacksonhinklle', '@LegitTargets', '@ACPMain', '@briebriejoy', '@BadFaithPod', '@RisingTheHill', '@theintercept', '@_whitneywebb']
# ----
# Key: RonFilipkowski
# Followers: ['@RonFilipkowski', '@JoJoFromJerz', '@MuellerSheWrote', '@MeidasTouch', '@AdamKinzinger', '@AirNatlGuard', '@thecountryfirst', '@TheRickWilson', '@RepSwalwell', '@HouseJudiciary', '@HomelandDems', '@duty2warn', '@marceelias', '@DemocracyDocket', '@EliasLawGroup', '@JDCocchiarella']
# ----
# Key: davidhogg111
# Followers: ['@davidhogg111', '@RepSwalwell', '@HouseJudiciary', '@HomelandDems', '@PeteButtigieg', '@SecretaryPete', '@MaryLTrump', '@RepRaskin', '@OversightDems', '@0liviajulianna', '@fred_guttenberg', '@RepKatiePorter', '@amyklobuchar', '@funder', '@TheDemCoalition', '@DworkinReport', '@DworkinWeekly']
# ----
# Key: anthonyzenkus
# Followers: ['@anthonyzenkus', '@SocialistMMA', '@RevBlackNetwork', '@ProudSocialist', '@AmpedUpPodcast', '@SarcasmStardust', '@action_4assange', '@SpiritofHo', '@geopoliticsha', '@SabbySabs2', '@Jaybefaunt', '@_Jaybefaunt', '@ajamubaraka', '@blacks4peace', '@LeeCamp', '@ThiaBallerina']
# ----
# Key: benshapiro
# Followers: ['@benshapiro', '@DonaldJTrumpJr', '@TheBabylonBee', '@dbongino', '@RealJamesWoods', '@libsoftiktok', '@bennyjohnson', '@MattWalshBlog', '@marklevinshow', '@Timcast', '@michaelmalice']
# ----
# Key: IngrahamAngle
# Followers: ['@IngrahamAngle', '@Jim_Jordan', '@JudiciaryGOP', '@Weaponization', '@DineshDSouza', '@RepMTG', '@ksorbs', '@tedcruz', '@heidiscruz', '@DiamondandSilk', '@RandPaul', '@mattgaetz', '@charliekirk11', '@TPUSA', '@TPAction_']
# ----
# Key: RealSpikeCohen
# Followers: ['@RealSpikeCohen', '@LPNational', '@beinlibertarian', '@LibertyLockPod', '@scotthortonshow', '@FreemansMind96', '@ToddHagopian', '@HannahDCox', '@whitecoatwaste', '@ThomasEWoods', '@checkmatestate', '@BobMurphyEcon', '@infineogroup']
# ----
# Key: briebriejoy
# Followers: ['@briebriejoy', '@ninaturner', '@RacePowerPolicy', '@KyleKulinski', '@davidsirota', '@LeverNews', '@EmilyforCO', '@aaronjmate', '@TheGrayzoneNews', '@UsefulIdiotpod', '@protonmail', '@ryangrim', '@DropSiteNews', '@SocialistMMA', '@RevBlackNetwork', '@krystalball', '@krystalmball', '@cushbomb', '@MaxBlumenthal']
# ----
# Key: ComicDaveSmith
# Followers: ['@ComicDaveSmith', '@michaelmalice', '@RealSpikeCohen', '@YATPOfficial', '@LPMisesCaucus', '@LibertyLockPod', '@scotthortonshow', '@FreemansMind96', '@angela4LNCChair', '@lpnational', '@ThomasEWoods', '@IanCrossland', '@MStockDesign', '@yannispappas']
# ----
# Key: TheRickWilson
# Followers: ['@TheRickWilson', '@mmpadellan', '@ReallyAmerican1', '@CalltoActivism', '@JoJoFromJerz', '@gtconway3d', '@PsychoPAC24', '@chkbal', '@TheAtlantic', '@itsJeffTiedrich', '@ProjectLincoln', '@robreiner', '@joncoopertweets', '@AdamKinzinger', '@AirNatlGuard', '@thecountryfirst']
# ----
# Key: FreemansMind96
# Followers: ['@FreemansMind96', '@scotthortonshow', '@ComicDaveSmith', '@gmail', '@LPMisesCaucus', '@RealSpikeCohen', '@YATPOfficial', '@DecampDave', '@protonmail', '@LibertyLockPod', '@DanielLMcAdams', '@Antiwarcom', '@antiwar', '@angela4LNCChair', '@lpnational']
# ----
# Key: HannahDCox
# Followers: ['@HannahDCox', '@TaylorDThinker', '@thereal_SnS', '@wethefemale', '@Burnett18', '@theFIREorg', '@MissLiyaP', '@Mercatus', '@GeorgeMasonU', '@BLS_gov', '@nyulaw', '@Forbes', '@suny', '@micah_erfan', '@TexasDemocrats', '@johnbryanesq', '@thecivilright', '@TheRabbitHole84', '@simonsays_La', '@KurtMAltman', '@REFORM', '@RepCloudTX', '@HouseAppropsGOP', '@GOPOversight', '@dankunsman', '@senjohnbarrasso', '@Josh_Young_1', '@eveforamerica', '@springssailor']
# ----
# Key: KyleKulinski
# Followers: ['@KyleKulinski', '@RashidaTlaib', '@zei_squirrel', '@gmail', '@AssalRad', '@90sWWE', '@WWE', '@WWENetwork', '@Daniel_Rapaport', '@wideofthepost', '@wideofthepost', '@mastodon', '@CantEverDie', '@WesternKabuki', '@CrateDiving', '@TheOnion', '@TrumpDailyPosts', '@RnaudBertrand', '@MarioNawfal', '@NSAGov', '@LouStagner', '@ArccosGolf', '@Titleist', '@HackItOutGolf', '@StrackaLine', '@PrincetonGolf', '@sk8ballin3', '@RepDeanPhillips', '@NYTimes', '@WSJ']
# ----
# Key: seanhannity
# Followers: ['@seanhannity', '@TheLeoTerrell', '@foxnews', '@jimmyfailla', '@SaraCarterDC', '@FoxNews', '@JustTheNews', '@peterschweizer', '@TheDrillDown1', '@GoldcoPM', '@danielhoffmanDC', '@concordiasummit', '@Govt_Acct_Inst', '@JoeTalkShow', '@realJeffreyLord', '@GreggJarrett', '@realDonaldTrump']
# ----
# Key: funder
# Followers: ['@funder', '@decman52', '@daviwat', '@lori00771', '@boiseidsteve', '@lmullinsdc', '@POLITICOMag', '@RoyHinkleyPhD', '@lijay1965', '@erosen1', '@WhoIsKF', '@awtoevs', '@TheDemocrats', '@ClimatePower', '@UtahDemocrats', '@kellumdander', '@kellumdander', '@mastodon', '@HaitianBridge', '@lanon_baccam', '@McdonaldRivet']
# ----
# Key: fred_guttenberg
# Followers: ['@fred_guttenberg', '@BrucePetillo', '@HeartitudeInc', '@alda', '@AlanAlda', '@RepRitchie', '@MichelleKinney', '@SenecaProjectUS', '@actorsequity', '@TheAdam027', '@JonesForAR', '@DirtRoadPAC', '@lindayaX', '@PennStateFball', '@KeepSheriffBob', '@LaurenMSuriel', '@Israelcc', '@EylonALevy', '@IsrCitizenSpox', '@StateofaPod', '@sexyliberaltour', '@gettinviggy', '@nytimes', '@ColinJost']
# ----
# Key: LeeCamp
# Followers: ['@LeeCamp', '@sdyy1', '@Outkast', '@kenklippenstein', '@gmail', '@CGTNRadio', '@ZombiePanther2', '@hyperobject_ind', '@weareyellowdot', '@Cancelcloco', '@FreeDanDuggan', '@Leipzig4A', '@d2thedre', '@Lebaneseraven', '@dpgcook', '@ActiveMeasures8', '@KitKlarenberg', '@RealAlexRubi', '@podcasting360', '@rishabhmjain', '@andrewjfaris', '@FRONTPAGE__', '@lunodavinci', '@TVFreePalestine', '@Xtawet']
# ----
# Key: JordanChariton
# Followers: ['@JordanChariton', '@17gamepace', '@rotounderworld', '@ESPN', '@JayarJackson', '@realDonaldTrump', '@SportMDAnalysis', '@FantasyPros', '@jtlarsen', '@GuruFantasyWrld', '@GuruFFWrld', '@Amy_K_Nelson', '@theriveterco', '@inc', '@Yamiche', '@NBCNews', '@KamalaHarris', '@Tim_Walz', '@nbcuni', '@AZAlawieh', '@uncommittedmvmt', '@luluelabed', '@mikeallen', '@MarkHalperin', '@2WAYtvapp', '@WaterWarriorOne']
# ----
# Key: mmpadellan
# Followers: ['@mmpadellan', '@CalltoActivism', '@JoJoFromJerz', '@itsJeffTiedrich', '@joncoopertweets', '@robreiner', '@MeidasTouch', '@MuellerSheWrote', '@TheRickWilson', '@RepAdamSchiff', '@RepJeffries', '@HouseDemocrats', '@MaryLTrump', '@RepSwalwell', '@HouseJudiciary', '@HomelandDems', '@ReallyAmerican1', '@donwinslow', '@WinslowBookClub', '@OccupyDemocrats', '@duty2warn', '@JDCocchiarella', '@tribelaw', '@JoyceWhiteVance', '@UALawSchool', '@MSNBC', '@NBCNews', '@RepRaskin', '@OversightDems']
# ----
# Key: charliekirk11
# Followers: ['@charliekirk11', '@WallStreetApes', '@joerogan', '@DonaldjTrumpJr', '@dbongino', '@mattgaetz', '@catturd2', '@JamesOKeefeIII', '@BryceHall', '@panthertalent', '@ChairmanWhatley', '@GOP', '@Mamalisa9300', '@MeanMachine505', '@LeoTheLion1964', '@ImmigrantCrimes', '@Will_Tanner_1', '@TAmTrib', '@vicentearenastv', '@NicoleShanahan', '@nicoleshanahan', '@CornelWest', '@OldRowOfficial', '@JamesBlairUSA', '@finkd', '@VitalikButerin', '@BryceMLipscomb']
# ----
# Key: davidsirota
# Followers: ['@davidsirota', '@SemaforComms', '@semafor', '@TheGoodLiars', '@jasonselvig', '@davramdavram', '@rebecca_John1', '@DeSmog', '@Airmail', '@mattzarb', '@gambanapp', '@premium', '@Ben_Inskeep', '@cacindiana', '@JacobFeldman4', '@Sportico', '@sundaylongread', '@thisdaypod', '@FixTheCourt', '@weeklyshowpod', '@DVNJr', '@AirMailWeekly', '@veronicaricco', '@levernews', '@ModeledBehavior', '@InnovateEconomy', '@Claudiashein', '@JWMason1']
# ----
# Key: kylegriffin1
# Followers: ['@kylegriffin1', '@RepAdamSchiff', '@TheRickWilson', '@gtconway3d', '@PsychoPAC24', '@chkbal', '@TheAtlantic', '@atrupar', '@SnapStream', '@marceelias', '@DemocracyDocket', '@EliasLawGroup', '@tedlieu', '@JoyceWhiteVance', '@UALawSchool', '@MSNBC', '@NBCNews', '@MollyJongFast', '@vanityfair', '@AdamParkhomenko']
# ----
# Key: TuckerCarlson
# Followers: ['@TuckerCarlson', '@TCNetwork']
# ----
# Key: elonmusk
# Followers: ['@elonmusk', '@jordanbpeterson', '@petersonacademy', '@DonaldJTrumpJr', '@TheBabylonBee', '@Jim_Jordan', '@JudiciaryGOP', '@Weaponization', '@lexfridman', '@DineshDSouza', '@benshapiro', '@benshapiroshow', '@SpaceX', '@RandPaul']
# ----
# Key: itsJeffTiedrich
# Followers: ['@itsJeffTiedrich', '@JoJoFromJerz', '@MeidasTouch', '@MuellerSheWrote', '@MaryLTrump', '@JoyceWhiteVance', '@UALawSchool', '@MSNBC', '@NBCNews', '@MollyJongFast', '@vanityfair', '@natsechobbyist', '@theswppod', '@BillKristol', '@caslernoel']
# ----
# Key: bluestein
# Followers: ['@bluestein', '@BeeForGeorgia', '@senatorwarnock', '@ajc', '@AuforGA', '@MurphyAJC', '@AJC', '@dailybeast', '@rollcall', '@gardenandgun', '@GeorgiaDemocrat', '@MaraDavis', '@podcastvote', '@pastemagazine', '@maradavis', '@jaysbookman', '@neonflag', '@markniesse']
# ----
# Key: krystalball
# Followers: ['@krystalball', '@KyleKulinski', '@ninaturner', '@RacePowerPolicy', '@esaagar', '@davidsirota', '@LeverNews', '@EmilyforCO', '@jimmy_dore', '@briebriejoy', '@BadFaithPod', '@RisingTheHill', '@theintercept', '@ryangrim', '@DropSiteNews', '@cenkuygur', '@TheYoungTurks', '@TYT', '@aaronjmate', '@TheGrayzoneNews', '@UsefulIdiotpod', '@protonmail']
# ----
# Key: SarcasmStardust
# Followers: ['@SarcasmStardust', '@aaronjmate', '@TheGrayzoneNews', '@UsefulIdiotpod', '@protonmail', '@SocialistMMA', '@RevBlackNetwork', '@FiorellaIsabelM', '@ProudSocialist', '@AmpedUpPodcast', '@SabbySabs2', '@SpiritofHo', '@geopoliticsha', '@PrimoRadical', '@anthonyzenkus', '@LeeCamp']
# ----
# Key: AnnCoulter
# Followers: ['@AnnCoulter', '@BreitbartNews', '@BuckSexton', '@clayandbuck', '@iheartradio', '@MZHemingway', '@FDRLST', '@Hillsdale', '@DailyCaller', '@jimmyfailla', '@JonathanTurley', '@TomCottonAR', '@SenTomCotton', '@LeeMZeldin', '@RepLeeZeldin', '@brithume']
# ----
# Key: SteveSchmidtSES
# Followers: ['@SteveSchmidtSES', '@robreiner', '@AdamKinzinger', '@AirNatlGuard', '@thecountryfirst', '@RepSwalwell', '@HouseJudiciary', '@HomelandDems', '@JoyceWhiteVance', '@UALawSchool', '@MSNBC', '@NBCNews', '@tribelaw', '@BeschlossDC', '@PBS', '@beschlossdc17', '@tedlieu', '@BillKristol', '@alfranken']
# ----
# Key: SocialistMMA
# Followers: ['@SocialistMMA', '@briebriejoy', '@BadFaithPod', '@RisingTheHill', '@theintercept', '@ProudSocialist', '@AmpedUpPodcast', '@Gritty20202', '@SabbySabs2', '@RevBlackNetwork', '@SpiritofHo', '@geopoliticsha', '@FiorellaIsabelM', '@SarcasmStardust', '@action_4assange', '@anthonyzenkus', '@Jaybefaunt', '@_Jaybefaunt']
# ----
# Key: gtconway3d
# Followers: ['@gtconway3d', '@ProjectLincoln', '@JoJoFromJerz', '@robreiner', '@TheRickWilson', '@AdamKinzinger', '@AirNatlGuard', '@thecountryfirst', '@joncoopertweets', '@RepAdamSchiff', '@MeidasTouch', '@RonFilipkowski']
# ----
# Key: ProudSocialist
# Followers: ['@ProudSocialist', '@briebriejoy', '@BadFaithPod', '@RisingTheHill', '@theintercept', '@SocialistMMA', '@RevBlackNetwork', '@Gritty20202', '@SarcasmStardust', '@action_4assange', '@anthonyzenkus', '@SpiritofHo', '@geopoliticsha', '@FiorellaIsabelM', '@SabbySabs2', '@ajamubaraka', '@blacks4peace']
# ----
# Key: checkmatestate
# Followers: ['@checkmatestate', '@ToddHagopian', '@angela4LNCChair', '@lpnational', '@scotthortonshow', '@FreemansMind96', '@ShaneTHazel', '@BobMurphyEcon', '@infineogroup', '@TheCajunLibert1', '@FreeStateNH', '@carynannharlos', '@PerBylund', '@okstate', '@Ratio_Institute', '@mises']
# ----
# Key: Josh_Moon
# Followers: ['@Josh_Moon', '@WarOnDumb', '@aldotcom', '@bshelburne', '@JohnArchibald', '@Niemanfdn', '@RepEngland70', '@lyman_brian', '@ALReflector', '@BecomingLincoln', '@ALReporter', '@willainsworthAL', '@reckonnews']
# ----
# Key: EricTrump
# Followers: ['@EricTrump', '@charliekirk11', '@TPUSA', '@TPAction_', '@w_terrence', '@DiamondandSilk', '@atensnut', '@RudyGiuliani', '@SebGorka', '@RyanAFournier', '@mtgreenee', '@BrandonStraka', '@RealWalkAway', '@brandonstraka']
# ----
# Key: LaraLeaTrump
# Followers: ['@LaraLeaTrump', '@TheLeoTerrell', '@foxnews', '@w_terrence', '@DiamondandSilk', '@SpeakerMcCarthy', '@RudyGiuliani', '@SebGorka', '@RonnyJacksonTX', '@SarahHuckabee', '@MonicaCrowley']
# ----
# Key: WarOnDumb
# Followers: ['@WarOnDumb', '@Josh_Moon', '@aldotcom', '@randallwoodfin', '@DougJones', '@bshelburne', '@JohnArchibald', '@Niemanfdn', '@ALostrich', '@RepTerriSewell', '@JoeGoodmanJr', '@ALdotcom']
# ----
# Key: robreiner
# Followers: ['@robreiner', '@mmpadellan', '@ReallyAmerican1', '@JoJoFromJerz', '@joncoopertweets', '@RepAdamSchiff', '@gtconway3d', '@PsychoPAC24', '@chkbal', '@TheAtlantic', '@TheRickWilson', '@MeidasTouch', '@AdamKinzinger', '@AirNatlGuard', '@thecountryfirst', '@MaryLTrump']
# ----
# Key: marceelias
# Followers: ['@marceelias', '@MuellerSheWrote', '@MeidasTouch', '@TheRickWilson', '@RepSwalwell', '@HouseJudiciary', '@HomelandDems', '@JoyceWhiteVance', '@UALawSchool', '@MSNBC', '@NBCNews', '@tribelaw', '@AVindman', '@natsechobbyist', '@votevets', '@MollyJongFast', '@vanityfair', '@IAmPoliticsGirl']
# ----
# Key: toddcstacy
# Followers: ['@toddcstacy', '@GovernorKayIvey', '@willainsworthAL', '@KatieBrittforAL', '@SenKatieBritt', '@AuburnFootball', '@coachbrucepearl', '@Josh_Moon', '@SenShelby', '@aldotcom', '@yhn']
# ----
