US election deniers who follow things outside the US saying that the Election in Brazil was stolen lmao.', 'Little edit: I said fringe in the above sentence but really it is quite a large majority of right wing voters now unfortunately.', 'This is the level of brain rot that has been occurring.', 'I just wanted to change that as a few people have mentioned it really isnt a minority anymore and in my opinion they are correct.', 'Free speech".', 'Uses the government to ban books Same camp as "privatize profits and socialize losses".', 'You would think it would get you banned from politics.', 'As weve seen in America this is clearly not the case Take them seriously.', 'There were right-winged laughing stocks in our country pulling the same stuff months before actual military coup.', 'The public just didnt take them seriously as some of the rightwing party doesnt even get a single vote.', 'Until they form a coalition and called for military coup and the junta who is ever power hungry actually went ahead and seized the power.', 'These two years had been nothing but misery for us.', 'Towns and villages are torched.', 'The military junta bomb the fk out of its own people to stop the resistance.', 'Million of ppl are suffering AND these guys are celebrating openly on Facebook and TikTok and such.', 'Take those people seriously.', 'Dealt with them accordingly.', 'These are nothing but cancer for society.', 'Dont let them grow at all.', 'As a Myanmar fuck the military coup.', 'Any politicians calling for one should be banned from politics.', 'They are the public enemy no.1 from that point on.', 'The dissonance required to lead a group named “Stop The Steal” and say that the military needs to override a democratic election and stage a coup is rather impressive!', 'More like Start the Steal or Resume the Steal.', 'Well have to deal with these nuts in a few days.']
portuguese_sentences = []
spanish_sentences = []
mixed_sentences = ['No man rules alone.', 'No man rules alone.', 'As a brazilian I can confirm.', 'Im so so happy he lost.', '(Im a bot).', 'FAQ( "Version 2.02 ~672677 tl;drs so far.").', 'No one!', 'Tropical Trump The MAGA of Brazil.', 'Fuck yes Lula!', 'To be fair Neymar didn’t have much of a chance.', 'Brazilian presidential incumbent Jair Bolsonaro just lost to former president Lula (short for Luiz Inácio Lula da Silva).', 'Oh it was stolen from me.', 'wahhhh.', 'GTFO.', 'If we win its fair if we lose its fraud.']
english_words = ['house', 'pile', 'documents', 'discarded', 'likely', 'described', 'article', 'found', 'added', 'taken', 'shredded', 'Ministry', 'Justice', 'course.', 'coup', 'attempt', 'coverup', 'imitated', 'Trump', 'point', 'plotting', 'coup', 'back', 'Brazil', 'trying', 'overturn', 'election', 'talking', 'election', 'thousand', 'brazilians', 'worst', 'economic', 'situation', 'currency', 'government', 'frozen', 'lack', 'funds', 'million', 'people', 'sleep', 'Lost', 'election', 'might', 'jail', 'SHIT', 'hope', 'suffers', 'last', 'days', 'people', 'environment', 'Brazil', 'hurts', 'soul', 'think', 'asshole', 'wannabe', 'dictator', 'really', 'really', 'fucked', 'take', 'youre', 'Brazil', 'correct', 'disagree', 'take', 'here', 'given', 'outcome', 'military', 'fact', 'completely', 'silent', 'leads', 'believe', 'holding', 'out', 'hope', 'military', 'make', 'indication', 'support', 'move', 'support', 'when', 'realized', 'wasnt', 'forthcoming', 'realized', 'choice', 'own', 'allies', 'abandoned', 'ship', 'fairly', 'quickly', 'really', 'fucking', 'quick', 'recognize', 'Leaders', 'world', 'congratulated', 'right', 'won', 'happened', 'political', 'leaders', 'country', 'allies', 'not', 'going', 'health', 'issues', 'related', 'infection', '
', 'when', 'supporters', 'stop', 'blocking/destroying', 'roads', 'country', 'Brazil', 'hurts', 'deleted', 'little', 'confused', 'got', 'spirit', 'guess', 'talked', 'protests', 'says', 'protests', 'thing', 'left', 'right', 'not', 'follow', 'democracy', 'Well', 'pleasant', 'surprise', 'wondering', 'though', 'got', 'else', 'sleeve', 'needs', 'tell', 'supporters', 'blocking', 'roads', 'highways', 'pretty', 'much', 'every', 'world', 'power', 'recognized', 'legitimate', 'winner', 'foreign', 'support', 'tries', 'tank', 'economy', 'hold', 'power', 'tried', 'major', 'states', 'fuckin', 'Putin', 'Russia', 'already', 'congratulated', 'victory', 'brazilian', 'generals', 'already', 'gave', 'hints', 'support', 'highly', 'respected', 'retired', 'survived', 'helicopter', 'hit', 'Hamilton', 'seems', 'not', 'support', 'money', 'people', 'Big', 'companies', 'want', 'coup', 'first', 'thought', 'why', 'might', 'answer', 'words', 'military', 'said', 'coup', 'really', 'hope', 'Brazil', 'fresh', 'start', 'idea', 'losing', 'candidates', 'publicly', 'elections', 'pretty', 'dangerous', 'Obviously', 'wonderful', 'unifying', 'when', 'helps', 'give', 'false', 'impression', 'election', 'results', 'ratified', 'losing', 'candidates', 'happens', 'election', 'results', 'somehow', 'question', 'Thats', 'not', 'how', 'work', 'remaining', 'silent', 'see', 'followers', 'create', 'chaos', 'call', 'coup', 'doesnt', 'work', 'always', 'claim', 'always', 'meant', 'accept', 'way', 'piece', 'shit', 'stay', 'silent', 'two', 'days', 'election', 'democracy', 'happy', 'lost', 'best', 'tl', 'make', 'reduced', 'bot', 'Truckers', 'protesters', 'Tuesday', 'blocked', 'highways', 'second', 'day', 'support', 'accept', 'election', 'loss', 'leftist', 'remained', 'largely', 'silent', 'election', 'results', 'announced', 'victory', 'recognized', 'allies', 'leaders', 'world', 'including', 'allies', 'Russia', 'offered', 'congratulations', 'Traffic', 'police', 'chief', 'fire', 'posting', 'story', 'election', 'day', 'urging', 'Brazilians', 'vote', 'Extended', 'Summary', 'tl', 'Feedback', 'comments', 'constructive', 'feedback', 'welcome.', 'Top', 'keywords', 'election', 't214ktow', 'Storming', 'saw', 'coming', 'Not', 'only', 'wealthy', 'people', 'least', 'likely', 'suffer', 'gain', 'vote', 'volunteer', 'uphold', 'democratic', 'institutions', 'sucked', 'back', 'authoritarianism', 'easy', 'forget', 'democracy', 'doesn', 't', 'happen—it', 'requires', 'people', 'care', 'institutions', 'start', 'disappear', 'soon', 'first', 'power-hungry', 'unscrupulous', 'comes', 'United', 'States', 'managed', 'survive', 'attempt', 'disregard', 'longstanding', 'traditions', 'institutional', 'norms', 'not', 'convinced', 'withstand', 'second', 'assault', 'people', 'positions', 'power', 'willing', 'pattern', 'equally', 'every', 'democracy', 'worst', 'wealthy', 'least', 'likely', 'suffer', 'll', 'ethnic', 'religious', 'minorities', 'poor', 'people', 'intelligentsia', 'hurt', 'History', 'replete', 'examples', 't', 'need', 'here', 'Exactly', 'whats', 'point', 'voting', 'candidates', 'accept', 'results', 'lose', 'main', 'thing', 'democratic', 'elections', 'designed', 'ensure', 'peaceful', 'transitions', 'power', 'extremely', 'dangerous', 'bullshit', 'Wait', 'seen', 'episode', 'Bannon', 'involved', 'family', 'helped', 'articulate', 'presidential', 'campaign', 'guessing', 'using', 'people', 'organize', 'imagination', 'simply', 'copying', 'Trump', 'Brazil', 'does', 'remind', 'Brazilian', 'see', 'political', 'nonsense', 'taking', 'place', 'here', 'Looks', 'voters', 'supporters', 'brainwashed', 'pretty', 'much', 'including', 'insurgence', 'military', 'coup', 'threatening', 'harassing', 'women', 'xenophobia', 'homophobia', 'support', 'desperately', 'need', 'intervention…', 'psychiatric', 'intervention', 'not', 'military', 'whenever', 'right', 'wingers', 'lose', 'elections', 'now', 'isn', 't', 'Learn', 'mistakes', 'start', 'throwing', 'back', 'people', 'youll', 'dealing', 'years', 'achieved', 'good', 'less', 'common', 'might', 'think', 'When', 'kid', 'quotes', 'famous', 'athletes', 'pages', 'quote', 'lines', 'brother', 'doctor', 'teacher', 'only', 'achieved', 'Lyon', 'dominating', 'french', 'league', 'best', 'players', 'striking', 'because', 'athletes', 'quotes', 'want', 'best', 'got', 'work', 'hard', 'every', 'day', 'believe', 'beat', 'etc', 'only', 'sounded', 'humble', 'intelligent', 'highlighted', 'Srs', 'mission', 'pretty', 'well', 'runs', 'business', 'wants', 'feel', 'when', 'doesnt', 'gets', 'martyrish', 'how', 'does', 'business', 'stops', 'playing', 'really', 'waste', 'hard', 'work', 'Seemed', 'relationship', 'really', 'athletes', 'last', 'people', 'ask', 'world', 'matters', 'especially', 'live', 'different', 'world', 'Fuck', 'fair', 'didn', 't', 'much', 'chance', 'spoilt', 'rotten', 'start', 'opportunistic', 'father', 'saw', 'family', 'route', 'riches', 'involved', 'sorts', 'shenanigans', 'notably', 'highly', 'contract', 'payments', 'direct', 'shame', 'mentality', 'seems', 'contaminated', 'surrounded', 'corruption', 'money', 'kid', 'people', 'expect', 'dunks', 'virgin', 'loving', 'Pulling', 'ladder', 'got', 'Doesnt', 'really', 'matter', 'now', 'Money', 'plenty', 'year', 'old', 'here', 'Brazilian', 'presidential', 'incumbent', 'lost', 'former', 'short', 'race', 'tumultuous', 'bookended', 'Highway', 'Police', 'suspected', 'thumb', 'attempting', 'stifle', 'voting', 'regions', 'polled', 'favourably', 'happening', 'Thanks', 'literally', 'said', 'options', 'Death', 'Arrest', 'Win', 'said', 'wasnt', 'going', 'arrested', 'knows', 'guy', 'going', 'pull', 'Trump', 'Oh', 'stolen', 'GTFO', 'correction', 'right', 'doesn', 'care', 'people', 'unless', 'agree', 'keep', 'power', 'money', 'influence', 'Policies', 'dammed', 'unless', 'helps', 'consolidate', 'retain', 'power', 'Conseding', 'shows', 'accept', 'people', 'right', 'doesnt', 'care', 'people', 'unless', 'agree', 'policies', 'love', 'new', 'everytime', 'right', 'loses', 'wait', 'beg', 'accept', 'results', 'cool', 'very', 'see', 'how', 'identify', 'far-right', 'loser', 'candidates', 'parties', 'Theyre', 'fucking', 'losers', 'accept', 'when', 'theyre', 'lost', 'theyre', 'clearly', 'fringe-minority', 'world', 'thinks', 'theyre', 'crazy', 'sudden', 'already', 'see', 'fringe', 'right', 'wing', 'election', 'deniers', 'follow', 'things', 'saying', 'Election', 'Brazil', 'stolen', 'Little', 'said', 'fringe', 'sentence', 'really', 'large', 'majority', 'right', 'wing', 'voters', 'now', 'unfortunately', 'level', 'brain', 'occurring', 'wanted', 'change', 'people', 'mentioned', 'really', 'minority', 'anymore', 'opinion', 'correct', 'Free', 'speech', 'Uses', 'government', 'books', 'privatize', 'profits', 'losses', 'win', 'fair', 'lose', 'think', 'get', 'banned', 'politics', 'weve', 'seen', 'clearly', 'not', 'case', 'Take', 'seriously', 'right-winged', 'laughing', 'stocks', 'country', 'pulling', 'stuff', 'months', 'military', 'coup', 'didnt', 'take', 'seriously', 'rightwing', 'party', 'doesnt', 'get', 'single', 'vote', 'coalition', 'called', 'military', 'coup', 'ever', 'power', 'hungry', 'actually', 'went', 'ahead', 'seized', 'power', 'two', 'years', 'misery', 'Towns', 'villages', 'torched', 'military', 'fk', 'out', 'own', 'people', 'stop', 'resistance', 'Million', 'ppl', 'suffering', 'guys', 'celebrating', 'openly', 'Facebook', 'Take', 'people', 'seriously', 'Dealt', 'cancer', 'society', 'grow', 'Myanmar', 'fuck', 'military', 'coup', 'politicians', 'calling', 'banned', 'politics', 'enemy', 'point', 'required', 'group', 'named', 'Stop', 'Steal', 'say', 'military', 'needs', 'override', 'democratic', 'election', 'stage', 'coup', 'impressive', 'More', 'Start', 'Steal', 'Steal', 'Well', 'nuts', 'days']
portuguese_words = ['Lula', 'Lula', 'Erysipelas', 'Lula', 'Lula', 'Congress', 'Lula', 'Lula', 'Lula', 'Congress', 'Lula', 'Lula', 'EU', 'Lula', 'Santos-Cruz', 'Mourao', 'Janeiro', 'Jair', 'Luiz', 'Lula', 'Silva', 'Lula', 'Silvinei', 'Instagram', 'FAQ', 'Lula', 'agenda', 'Juninho', 'Neymar', 'Lula', 'Neymar', 'Neymar', 'moleque', 'mimado', 'Neymar', 'Juninho', 'Neymar', 'Jair', 'Lula', 'Luiz', 'Inácio', 'Lula', 'Silva', 'Lula', 'Portuguese', 'lmao']
spanish_words = ['due', 'Bolsonaro', 'due', 'Bolsonaro', 'Bolsonaro', 'Bolsonaro', 'period', 'CGP', 'alone', 'Bolsonaro', 'CGP', 'alone', 'Bolsonaro', 'Bolsonaro', 'Inacio', 'Lulas', 'Bolsonaro', 'Bolsonaro', 'Bolsonaro', 'Cerberusz', 'Bolsonaro', 'Bolsonaro', 'ones', 'Barcelona', 'Mbappé', 'Bolsonaro', 'Bolsonaro', 'actual']
mixed_words= ['material', '.so', '?', 'sent', 'face', 'trial', 'result', 'Hes', 'game', '?', '800', 'dead', 'Real', '33', 'famine', 'I', 'go', 'crimes', 'REAL', 'I', 'planet', 'did', 'I', 'I', 'result', 'sort', 'no', 'concede', '1', '2', 'same', 'even', 's', '3', 'confirmed', 'leg', 'I', 'don', 's', 'go', 's', 'I', 'no', 'fraud', 'credit', 'civil', 'gist', 'No', 'man', 'Even', 'even', 're', 'once', 's', 'contingent', 'Jan', 'did', 'Biden', 'man', 'con', 'apart', 'I', 'cant', 'result', 'time', 's', 'I', 'did', '1-7', 'credit', 'civil', 'gist', 'No', 'man', 'Even', 'even', 're', 'once', 's', 'contingent', 'Jan', 'did', 'Biden', 'man', 'con', 'apart', 'I', 'cant', 'result', 'time', 's', 'I', 'did', '1-7', 's', 's', 'I', 'violent', 'do', 'same', 's', 's', 'go', 'home', 'wont', 'even', 'China', 'even', 'I', 'confirm', 'wont', 'general', 'Congo', ';', 'vice-president', 'General', 'dont', '?', ';', 'no', 'I', 'true', 'concede', 'do', 'problem', ';', 'democracies', 'I', 'assume', 'hes', 'result', 'dont', 'Im', ';', 'dr', 'I', 'original', '70', '%', 'Im', 'Rio', 'de', 'President', 'da', 'president', 'president', 'China', 'Vasques', 'came', 'Version', '2.02', '~672677', ';', 'drs', 'far.', 'PMs', 'monitored', 'President', 'Rio', ',', 'worldnews', ',', ',', ',', 't1iumu16y', ',', 't1iummtyj', ',', '11/01/22', '11:13', ',', '2', ',', '1304', ',', '0', ',', 'capital', '3…2…1', 'No', 'No', 's', 'just', 'populist', 'I', 'm', 'defend', 'true', 'part', 'I', 'don', 'even', 'list', 'dont', '?', 'I', 've', '2018', 'Im', 'same', 'no', 'hes', 'idol', 'Tropical', 'MAGA', 'I', 'm', 's', 'sad', 's', 'do', 'racism', 'lunatic', 'one…', 'gon', 'na', 'norm', '?', 'Americas', 'human', 'I', 'I', 'sister', 'I', 'time', 'Netflix', 'doc', 'son', 'CEO', 'brand', 'hes', 'Jr', 'do', 'part', 'Sr', 'Jr', 'Jr', 'gon', 'na', 'miserable', 'real', 'star', 'yes', 's', 'financial', 'illegal', 'corrupt', 'table', 'Sr.', 'do', '?', 'Chad', 'sister', 'once', 'come', '6', 'just', 'president', 'da', 'Federal', 's', 'ELI5', '3', 'wahhhh', 'Far', 'let', 'Far', 'I', 'era', 'global', 'far', 'Super', 'normal', 'I', 'dont', 'sore', 'cant', 'rest', 'stupid', 'ignorant', 'morons', 'fluent', 'lol', 'I', 'edit', 'I', 'quite', 'rot', 'I', 'just', 'isnt', 'ban', 'Same', 'camp', 'socialize', 'fraud', 'America', 'same', 'public', 'just', 'even', 'form', 'junta', 'junta', 'bomb', 'TikTok', 'Dont', 'let', 'public', 'no.1', 'dissonance', 'lead', 'Resume', 'deal']

f = open('stop words.txt', 'r')
stopwords = f.read()
stopwords = stopwords.split('\n')

def filter(words: list):
    result = []
    for word in words:
        if word.lower().strip() not in stopwords and len(word) != 1 and word.lower() not in result:
            result.append(word.lower())
    return result

english_words = filter(english_words)
portuguese_words = filter(portuguese_words)
spanish_words = filter(spanish_words)
mixed_words = filter(mixed_words)

f.close()

# %%
import csv 
import os
   
import pandas as pd 
import spacy 
# spacy.cli.download("pt_core_news_sm")
# spacy.cli.download("es_core_news_sm")

import requests 
from bs4 import BeautifulSoup
from dataclasses import dataclass

#Sentence Tokenization using sent_tokenize
import nltk
# nltk.download('punkt')
from nltk import word_tokenize,sent_tokenize
from nltk.tokenize import word_tokenize

#Detect language using detect_langs
import langdetect
from langdetect import detect_langs

#Detect language using Lingua
from lingua import Language, LanguageDetectorBuilder

@dataclass
class entities:
    name: str
    label: str

#strip out the pronouns, conjunctions, etc.!
f = open('stop words.txt', 'r')
stopwords = f.read()
stopwords = stopwords.split('\n')

# Load the spaCy English & Portuguese models
en_nlp = spacy.load("en_core_web_sm")
pt_nlp = spacy.load('pt_core_news_sm')

pd.set_option("display.max_rows", 200)

PeopleS = []
PeopleW = []

en_doc = en_nlp(" ".join(english_sentences) + " ".join(mixed_sentences))
# pt_doc = pt_nlp()

for ent in en_doc.ents:
    # The output displayed the names of the entities and their predicted labels.
    if ent.text not in PeopleS and ent.label_ == 'PERSON':
        # PeopleS.append(entities(ent.text, ent.label_))
        PeopleS.append(ent.text)

print(PeopleS)

for word in english_words:
    en_word = en_nlp(word)
    for ent in en_word.ents:
        if ent.text not in PeopleW and ent.label_ == 'PERSON':
            PeopleW.append(ent.text)

for word in portuguese_words:
    pt_word = pt_nlp(word)
    for ent in pt_word.ents:
        if ent.text not in PeopleW and ent.label_ == 'PER' or ent.label_ == 'LOC':
            PeopleW.append(ent.text)

for word in spanish_words:
    es_word = pt_nlp(word)
    for ent in es_word.ents:
        if ent.text not in PeopleW and ent.label_ == 'PER' or ent.label_ == 'LOC':
            PeopleW.append(ent.text)

print(PeopleW)

People = PeopleW + PeopleS
# Out:
# ['Bolsonaro', 'Lula', 'Erysipelas', 'Biden', 'Putin', 'Santos-Cruz', 'Hamilton Mourao', 'Jair Bolsonaro', 'Luiz Inacio Lula da Silva', 'Lulas', 'Silvinei Vasques', 'Lula Bolsonaro', 'Cerberusz', 'Storming', 'Bannon', 'Lyon', 'Netflix Neymar', 'Jr', 'Neymar Sr', 'Mbappé', 'Neymar', 'Neymar Pulling', 'Death Arrest Win', 'da Silva', 'GTFO']
# ['putin', 'hamilton', 'isn', 'lyon', 'gtfo', 'loser', 'erysipelas', 'congress', 'santos-cruz', 'mourao', 'luiz', 'silvinei', 'agenda', 'juninho', 'moleque', 'portuguese', 'lmao', 'bolsonaro', 'period', 'cgp', 'inacio', 'lulas', 'cerberusz', 'ones', 'barcelona']
# ...

# %%
from polyglot.downloader import downloader

from polyglot.text import Text
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from polyglot.downloader import downloader
#       3 from polyglot.text import Text
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polyglot/downloader.py:91
#      87 from json import loads
#      90 from polyglot import polyglot_path
# ---> 91 from polyglot.detect.langids import isoLangs
#      92 from polyglot.utils import pretty_list
#      93 from icu import Locale
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polyglot/detect/__init__.py:1
# ----> 1 from .base import Detector, Language
#       3 __all__ = ['Detector', 'Language']
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polyglot/detect/base.py:11
#       5 """Detecting languages"""
#       8 import logging
# ...
