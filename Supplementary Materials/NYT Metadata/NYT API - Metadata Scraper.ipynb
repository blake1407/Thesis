# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
import json
import logging
from pathlib import Path
import calendar

class NYTArticleScraper:
    def __init__(self, api_key, query, start_date, end_date=None):
        """
        Initialize the NYT Article Scraper
        
        Parameters:
        api_key (str): NYT API key
        query (str): Search query
        start_date (str): Start date in YYYYMMDD format
        end_date (str): Optional end date in YYYYMMDD format
        """
        self.api_key = api_key
        self.base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"
        self.query = query
        self.start_date = start_date
        self.end_date = end_date or start_date
        self.daily_requests = 0
        self.last_request_time = None
        self.current_date = datetime.now().strftime('%Y%m%d')
        
        # Setup logging
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s',
            handlers=[
                logging.FileHandler('Raw Data/NYT_Scraper.log'),
                logging.StreamHandler()
            ]
        )
        self.logger = logging.getLogger(__name__)
        
    def wait_for_rate_limit(self):
        """Manage API rate limits"""
        # Check if we need to reset daily counter
        current_date = datetime.now().strftime('%Y%m%d')
        if current_date != self.current_date:
            self.daily_requests = 0
            self.current_date = current_date
        
        # Check daily limit
        if self.daily_requests >= 500:
            wait_time = (datetime.now() + timedelta(days=1)).replace(
                hour=0, minute=0, second=0, microsecond=0
            ) - datetime.now()
            self.logger.info(f"Daily limit reached. Waiting {wait_time.seconds} seconds until midnight...")
            time.sleep(wait_time.seconds + 1)
            self.daily_requests = 0
            self.current_date = datetime.now().strftime('%Y%m%d')
        
        # Handle per-minute rate limit
        if self.last_request_time is not None:
            elapsed = time.time() - self.last_request_time
            if elapsed < 12:
                time.sleep(12 - elapsed)
        
        self.last_request_time = time.time()
        self.daily_requests += 1
        
    def get_params(self, page, current_date):
        """Generate parameters for API request"""
        return {
            'q': self.query,
            'news_desk': 'World;Politics',
            'begin_date': current_date,
            'end_date': current_date,
            'type_of_material': 'News',
            'api-key': self.api_key,
            'page': page,
            'sort': 'oldest'
        }
    
    def process_article(self, article):
        """Process a single article and extract relevant information"""
        try:
            persons = [kw['value'] for kw in article['keywords'] if kw['name'] == 'persons']
            places = [kw['value'] for kw in article['keywords'] if kw['name'] == 'glocations']
            subjects = [kw['value'] for kw in article['keywords'] if kw['name'] == 'subject']
            organizations = [kw['value'] for kw in article['keywords'] if kw['name'] == 'organizations']
            
            return {
                'headline': article['headline']['main'],
                'publication_date': pd.to_datetime(article['pub_date']),
                'people_mentioned': '; '.join(persons),
                'places_mentioned': '; '.join(places),
                'subjects': '; '.join(subjects),
                'organizations': '; '.join(organizations),
                'url': article['web_url'],
                'abstract': article.get('abstract', ''),
                'word_count': article.get('word_count', 0),
            }
        except KeyError as e:
            self.logger.error(f"Error processing article: {e}")
            return None
    
    def get_month_range(self, date_str):
        """Get the start and end date for a month containing the given date"""
        date = datetime.strptime(date_str, '%Y%m%d')
        _, last_day = calendar.monthrange(date.year, date.month)
        month_start = date.replace(day=1).strftime('%Y%m%d')
        month_end = date.replace(day=last_day).strftime('%Y%m%d')
        return month_start, month_end
    
    def fetch_articles_for_date(self, current_date):
        """Fetch all articles for a specific date"""
        page = 0
        articles_for_date = []
        
        while True:
            try:
                self.logger.info(f"Fetching page {page} for date {current_date} (Daily requests: {self.daily_requests}/500)")
                self.wait_for_rate_limit()
                
                params = self.get_params(page, current_date)
                response = requests.get(self.base_url, params=params)
                response.raise_for_status()
                data = response.json()
                
                if 'response' not in data or not data['response']['docs']:
                    break
                    
                processed_articles = [
                    article for article in [
                        self.process_article(doc) 
                        for doc in data['response']['docs']
                    ] 
                    if article is not None
                ]
                
                articles_for_date.extend(processed_articles)
                self.logger.info(f"Found {len(processed_articles)} articles on page {page}")
                
                # Check if we've reached the last page
                if len(data['response']['docs']) < 10:
                    break
                    
                page += 1
                
            except requests.exceptions.RequestException as e:
                self.logger.error(f"API request failed for date {current_date}, page {page}: {e}")
                break
            except json.JSONDecodeError as e:
                self.logger.error(f"JSON parsing error for date {current_date}, page {page}: {e}")
                break
            
        return articles_for_date
    
    def fetch_articles_by_month(self):
        """Fetch articles month by month"""
        current_date = datetime.strptime(self.start_date, '%Y%m%d')
        end_date = datetime.strptime(self.end_date, '%Y%m%d')
        
        while current_date <= end_date:
            # Get month range
            month_start, month_end = self.get_month_range(current_date.strftime('%Y%m%d'))
            month_articles = []
            
            # Process each day in the month
            current_day = max(current_date, datetime.strptime(month_start, '%Y%m%d'))
            month_end_date = min(end_date, datetime.strptime(month_end, '%Y%m%d'))
            
            while current_day <= month_end_date:
                current_day_str = current_day.strftime('%Y%m%d')
                self.logger.info(f"Processing date: {current_day_str}")
                
                articles = self.fetch_articles_for_date(current_day_str)
                month_articles.extend(articles)
                
                # # Save progress after each day
                # if articles:
                #     progress_file = month_dir / f'NYT_Articles_{current_day_str}.csv'
                #     pd.DataFrame(articles).to_csv(progress_file, index=False)
                #     self.logger.info(f"Saved {len(articles)} articles for {current_day_str}")
                
                current_day += timedelta(days=1)
            
            # Save month's articles
            if month_articles:
                monthly_file = f'Raw Data/NYT_Articles_{current_date.strftime("%Y_%m")}.csv'
                df = pd.DataFrame(month_articles)
                df.to_csv(monthly_file, index=False)
                self.logger.info(f"Saved {len(month_articles)} articles for {current_date.strftime('%Y-%m')} to {monthly_file}")
            
            # Move to first day of next month
            current_date = (current_date.replace(day=28) + timedelta(days=4)).replace(day=1)

def main():
    # Configuration
    API_KEY = "RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb"
    QUERY = "Israel-Gaza War (2023-)"
    START_DATE = "20240607"
    END_DATE = "20241007"
    
    # Initialize and run scraper
    scraper = NYTArticleScraper(
        api_key=API_KEY,
        query=QUERY,
        start_date=START_DATE,
        end_date=END_DATE
    )
    
    scraper.fetch_articles_by_month()

if __name__ == "__main__":
    main()
# Out:
# 2024-11-16 23:00:10,596 - INFO - Processing date: 20240607
# 2024-11-16 23:00:10,596 - INFO - Fetching page 0 for date 20240607 (Daily requests: 0/500)
# 2024-11-16 23:00:11,181 - INFO - Found 10 articles on page 0
# 2024-11-16 23:00:11,183 - INFO - Fetching page 1 for date 20240607 (Daily requests: 1/500)
# 2024-11-16 23:00:23,034 - INFO - Found 1 articles on page 1
# 2024-11-16 23:00:23,036 - INFO - Processing date: 20240608
# 2024-11-16 23:00:23,037 - INFO - Fetching page 0 for date 20240608 (Daily requests: 2/500)
# 2024-11-16 23:00:35,156 - INFO - Found 10 articles on page 0
# 2024-11-16 23:00:35,157 - INFO - Fetching page 1 for date 20240608 (Daily requests: 3/500)
# 2024-11-16 23:00:47,103 - INFO - Found 4 articles on page 1
# 2024-11-16 23:00:47,114 - INFO - Processing date: 20240609
# 2024-11-16 23:00:47,115 - INFO - Fetching page 0 for date 20240609 (Daily requests: 4/500)
# 2024-11-16 23:00:59,057 - INFO - Found 9 articles on page 0
# 2024-11-16 23:00:59,058 - INFO - Processing date: 20240610
# 2024-11-16 23:00:59,059 - INFO - Fetching page 0 for date 20240610 (Daily requests: 5/500)
# 2024-11-16 23:01:11,193 - INFO - Found 10 articles on page 0
# 2024-11-16 23:01:11,193 - INFO - Fetching page 1 for date 20240610 (Daily requests: 6/500)
# 2024-11-16 23:01:23,021 - INFO - Found 1 articles on page 1
# 2024-11-16 23:01:23,023 - INFO - Processing date: 20240611
# 2024-11-16 23:01:23,024 - INFO - Fetching page 0 for date 20240611 (Daily requests: 7/500)
# 2024-11-16 23:01:35,171 - INFO - Found 10 articles on page 0
# 2024-11-16 23:01:35,171 - INFO - Fetching page 1 for date 20240611 (Daily requests: 8/500)
# 2024-11-16 23:01:47,070 - INFO - Found 3 articles on page 1
# 2024-11-16 23:01:47,071 - INFO - Processing date: 20240612
# 2024-11-16 23:01:47,072 - INFO - Fetching page 0 for date 20240612 (Daily requests: 9/500)
# 2024-11-16 23:01:59,095 - INFO - Found 10 articles on page 0
# 2024-11-16 23:01:59,096 - INFO - Fetching page 1 for date 20240612 (Daily requests: 10/500)
# 2024-11-16 23:02:11,122 - INFO - Found 1 articles on page 1
# 2024-11-16 23:02:11,124 - INFO - Processing date: 20240613
# 2024-11-16 23:02:11,124 - INFO - Fetching page 0 for date 20240613 (Daily requests: 11/500)
# 2024-11-16 23:02:23,080 - INFO - Found 6 articles on page 0
# 2024-11-16 23:02:23,082 - INFO - Processing date: 20240614
# 2024-11-16 23:02:23,083 - INFO - Fetching page 0 for date 20240614 (Daily requests: 12/500)
# 2024-11-16 23:02:35,140 - INFO - Found 8 articles on page 0
# 2024-11-16 23:02:35,142 - INFO - Processing date: 20240615
# 2024-11-16 23:02:35,143 - INFO - Fetching page 0 for date 20240615 (Daily requests: 13/500)
# 2024-11-16 23:02:47,188 - INFO - Found 5 articles on page 0
# 2024-11-16 23:02:47,190 - INFO - Processing date: 20240616
# 2024-11-16 23:02:47,191 - INFO - Fetching page 0 for date 20240616 (Daily requests: 14/500)
# 2024-11-16 23:02:59,135 - INFO - Found 4 articles on page 0
# 2024-11-16 23:02:59,136 - INFO - Processing date: 20240617
# 2024-11-16 23:02:59,136 - INFO - Fetching page 0 for date 20240617 (Daily requests: 15/500)
# 2024-11-16 23:03:11,250 - INFO - Found 10 articles on page 0
# 2024-11-16 23:03:11,251 - INFO - Fetching page 1 for date 20240617 (Daily requests: 16/500)
# 2024-11-16 23:03:23,064 - INFO - Found 1 articles on page 1
# 2024-11-16 23:03:23,065 - INFO - Processing date: 20240618
# 2024-11-16 23:03:23,065 - INFO - Fetching page 0 for date 20240618 (Daily requests: 17/500)
# 2024-11-16 23:03:35,160 - INFO - Found 9 articles on page 0
# 2024-11-16 23:03:35,161 - INFO - Processing date: 20240619
# 2024-11-16 23:03:35,161 - INFO - Fetching page 0 for date 20240619 (Daily requests: 18/500)
# 2024-11-16 23:03:47,156 - INFO - Found 4 articles on page 0
# 2024-11-16 23:03:47,157 - INFO - Processing date: 20240620
# 2024-11-16 23:03:47,159 - INFO - Fetching page 0 for date 20240620 (Daily requests: 19/500)
# 2024-11-16 23:03:59,177 - INFO - Found 8 articles on page 0
# 2024-11-16 23:03:59,178 - INFO - Processing date: 20240621
# 2024-11-16 23:03:59,180 - INFO - Fetching page 0 for date 20240621 (Daily requests: 20/500)
# 2024-11-16 23:04:11,220 - INFO - Found 2 articles on page 0
# 2024-11-16 23:04:11,221 - INFO - Processing date: 20240622
# 2024-11-16 23:04:11,222 - INFO - Fetching page 0 for date 20240622 (Daily requests: 21/500)
# 2024-11-16 23:04:23,247 - INFO - Found 9 articles on page 0
# 2024-11-16 23:04:23,248 - INFO - Processing date: 20240623
# 2024-11-16 23:04:23,249 - INFO - Fetching page 0 for date 20240623 (Daily requests: 22/500)
# 2024-11-16 23:04:35,229 - INFO - Found 2 articles on page 0
# 2024-11-16 23:04:35,230 - INFO - Processing date: 20240624
# 2024-11-16 23:04:35,231 - INFO - Fetching page 0 for date 20240624 (Daily requests: 23/500)
# 2024-11-16 23:04:47,263 - INFO - Found 9 articles on page 0
# 2024-11-16 23:04:47,264 - INFO - Processing date: 20240625
# 2024-11-16 23:04:47,265 - INFO - Fetching page 0 for date 20240625 (Daily requests: 24/500)
# 2024-11-16 23:04:59,265 - INFO - Found 7 articles on page 0
# 2024-11-16 23:04:59,266 - INFO - Processing date: 20240626
# 2024-11-16 23:04:59,267 - INFO - Fetching page 0 for date 20240626 (Daily requests: 25/500)
# 2024-11-16 23:05:11,269 - INFO - Found 10 articles on page 0
# 2024-11-16 23:05:11,270 - INFO - Fetching page 1 for date 20240626 (Daily requests: 26/500)
# 2024-11-16 23:05:23,223 - INFO - Processing date: 20240627
# 2024-11-16 23:05:23,224 - INFO - Fetching page 0 for date 20240627 (Daily requests: 27/500)
# 2024-11-16 23:05:35,344 - INFO - Found 8 articles on page 0
# 2024-11-16 23:05:35,345 - INFO - Processing date: 20240628
# 2024-11-16 23:05:35,346 - INFO - Fetching page 0 for date 20240628 (Daily requests: 28/500)
# 2024-11-16 23:05:47,287 - INFO - Found 2 articles on page 0
# 2024-11-16 23:05:47,288 - INFO - Processing date: 20240629
# 2024-11-16 23:05:47,288 - INFO - Fetching page 0 for date 20240629 (Daily requests: 29/500)
# 2024-11-16 23:05:59,309 - INFO - Found 2 articles on page 0
# 2024-11-16 23:05:59,311 - INFO - Processing date: 20240630
# 2024-11-16 23:05:59,312 - INFO - Fetching page 0 for date 20240630 (Daily requests: 30/500)
# 2024-11-16 23:19:36,015 - INFO - Fetching page 1 for date 20240828 (Daily requests: 98/500)
# 2024-11-16 23:19:47,923 - INFO - Found 1 articles on page 1
# 2024-11-16 23:19:47,924 - INFO - Processing date: 20240829
# 2024-11-16 23:19:47,924 - INFO - Fetching page 0 for date 20240829 (Daily requests: 99/500)
# 2024-11-16 23:19:59,965 - INFO - Found 6 articles on page 0
# 2024-11-16 23:19:59,967 - INFO - Processing date: 20240830
# 2024-11-16 23:19:59,968 - INFO - Fetching page 0 for date 20240830 (Daily requests: 100/500)
# 2024-11-16 23:20:12,021 - INFO - Found 8 articles on page 0
# 2024-11-16 23:20:12,022 - INFO - Processing date: 20240831
# 2024-11-16 23:20:12,023 - INFO - Fetching page 0 for date 20240831 (Daily requests: 101/500)
# 2024-11-16 23:20:23,932 - INFO - Found 4 articles on page 0
# 2024-11-16 23:20:23,939 - INFO - Saved 216 articles for 2024-08 to Raw Data/NYT_Articles_2024_08.csv
# 2024-11-16 23:20:23,940 - INFO - Processing date: 20240901
# 2024-11-16 23:20:23,941 - INFO - Fetching page 0 for date 20240901 (Daily requests: 102/500)
# 2024-11-16 23:20:36,028 - INFO - Found 9 articles on page 0
# 2024-11-16 23:20:36,030 - INFO - Processing date: 20240902
# 2024-11-16 23:20:36,030 - INFO - Fetching page 0 for date 20240902 (Daily requests: 103/500)
# 2024-11-16 23:20:47,982 - INFO - Found 10 articles on page 0
# 2024-11-16 23:20:47,983 - INFO - Fetching page 1 for date 20240902 (Daily requests: 104/500)
# 2024-11-16 23:20:59,973 - INFO - Found 1 articles on page 1
# 2024-11-16 23:20:59,973 - INFO - Processing date: 20240903
# 2024-11-16 23:20:59,975 - INFO - Fetching page 0 for date 20240903 (Daily requests: 105/500)
# 2024-11-16 23:21:11,996 - INFO - Found 8 articles on page 0
# 2024-11-16 23:21:11,998 - INFO - Processing date: 20240904
# 2024-11-16 23:21:11,999 - INFO - Fetching page 0 for date 20240904 (Daily requests: 106/500)
# 2024-11-16 23:21:24,009 - INFO - Found 5 articles on page 0
# 2024-11-16 23:21:24,010 - INFO - Processing date: 20240905
# 2024-11-16 23:21:24,011 - INFO - Fetching page 0 for date 20240905 (Daily requests: 107/500)
# 2024-11-16 23:21:36,038 - INFO - Found 3 articles on page 0
# 2024-11-16 23:21:36,039 - INFO - Processing date: 20240906
# 2024-11-16 23:21:36,040 - INFO - Fetching page 0 for date 20240906 (Daily requests: 108/500)
# 2024-11-16 23:21:48,017 - INFO - Found 9 articles on page 0
# 2024-11-16 23:21:48,019 - INFO - Processing date: 20240907
# 2024-11-16 23:21:48,020 - INFO - Fetching page 0 for date 20240907 (Daily requests: 109/500)
# 2024-11-16 23:22:00,045 - INFO - Found 5 articles on page 0
# 2024-11-16 23:22:00,046 - INFO - Processing date: 20240908
# 2024-11-16 23:22:00,048 - INFO - Fetching page 0 for date 20240908 (Daily requests: 110/500)
# 2024-11-16 23:22:12,008 - INFO - Found 2 articles on page 0
# 2024-11-16 23:22:12,009 - INFO - Processing date: 20240909
# 2024-11-16 23:22:12,010 - INFO - Fetching page 0 for date 20240909 (Daily requests: 111/500)
# 2024-11-16 23:22:23,998 - INFO - Found 2 articles on page 0
# 2024-11-16 23:22:23,999 - INFO - Processing date: 20240910
# 2024-11-16 23:22:24,000 - INFO - Fetching page 0 for date 20240910 (Daily requests: 112/500)
# 2024-11-16 23:22:36,132 - INFO - Found 10 articles on page 0
# 2024-11-16 23:22:36,133 - INFO - Fetching page 1 for date 20240910 (Daily requests: 113/500)
# 2024-11-16 23:22:48,025 - INFO - Found 3 articles on page 1
# 2024-11-16 23:22:48,026 - INFO - Processing date: 20240911
# 2024-11-16 23:22:48,027 - INFO - Fetching page 0 for date 20240911 (Daily requests: 114/500)
# 2024-11-16 23:23:00,038 - INFO - Found 6 articles on page 0
# 2024-11-16 23:23:00,039 - INFO - Processing date: 20240912
# 2024-11-16 23:23:00,040 - INFO - Fetching page 0 for date 20240912 (Daily requests: 115/500)
# 2024-11-16 23:23:12,038 - INFO - Found 5 articles on page 0
# 2024-11-16 23:23:12,039 - INFO - Processing date: 20240913
# 2024-11-16 23:23:12,040 - INFO - Fetching page 0 for date 20240913 (Daily requests: 116/500)
# 2024-11-16 23:23:24,075 - INFO - Found 5 articles on page 0
# 2024-11-16 23:23:24,076 - INFO - Processing date: 20240914
# 2024-11-16 23:23:24,076 - INFO - Fetching page 0 for date 20240914 (Daily requests: 117/500)
# 2024-11-16 23:23:36,082 - INFO - Found 2 articles on page 0
# 2024-11-16 23:23:36,083 - INFO - Processing date: 20240915
# 2024-11-16 23:23:36,084 - INFO - Fetching page 0 for date 20240915 (Daily requests: 118/500)
# 2024-11-16 23:23:48,063 - INFO - Found 3 articles on page 0
# 2024-11-16 23:23:48,064 - INFO - Processing date: 20240916
# 2024-11-16 23:23:48,065 - INFO - Fetching page 0 for date 20240916 (Daily requests: 119/500)
# 2024-11-16 23:24:00,090 - INFO - Found 3 articles on page 0
# 2024-11-16 23:24:00,092 - INFO - Processing date: 20240917
# 2024-11-16 23:24:00,093 - INFO - Fetching page 0 for date 20240917 (Daily requests: 120/500)
# 2024-11-16 23:24:12,176 - INFO - Found 10 articles on page 0
# 2024-11-16 23:24:12,176 - INFO - Fetching page 1 for date 20240917 (Daily requests: 121/500)
# 2024-11-16 23:24:23,976 - INFO - Processing date: 20240918
# 2024-11-16 23:24:23,978 - INFO - Fetching page 0 for date 20240918 (Daily requests: 122/500)
# 2024-11-16 23:24:36,128 - INFO - Found 10 articles on page 0
# 2024-11-16 23:24:36,129 - INFO - Fetching page 1 for date 20240918 (Daily requests: 123/500)
# 2024-11-16 23:24:47,991 - INFO - Processing date: 20240919
# 2024-11-16 23:24:47,992 - INFO - Fetching page 0 for date 20240919 (Daily requests: 124/500)
# 2024-11-16 23:25:00,160 - INFO - Found 9 articles on page 0
# 2024-11-16 23:25:00,162 - INFO - Processing date: 20240920
# 2024-11-16 23:25:00,163 - INFO - Fetching page 0 for date 20240920 (Daily requests: 125/500)
# 2024-11-16 23:25:12,239 - INFO - Found 10 articles on page 0
# 2024-11-16 23:25:12,240 - INFO - Fetching page 1 for date 20240920 (Daily requests: 126/500)
# 2024-11-16 23:25:24,063 - INFO - Processing date: 20240921
# 2024-11-16 23:25:24,065 - INFO - Fetching page 0 for date 20240921 (Daily requests: 127/500)
# 2024-11-16 23:25:36,167 - INFO - Found 6 articles on page 0
# 2024-11-16 23:25:36,170 - INFO - Processing date: 20240922
# 2024-11-16 23:25:36,171 - INFO - Fetching page 0 for date 20240922 (Daily requests: 128/500)
# 2024-11-16 23:25:48,178 - INFO - Found 4 articles on page 0
# 2024-11-16 23:25:48,179 - INFO - Processing date: 20240923
# 2024-11-16 23:25:48,180 - INFO - Fetching page 0 for date 20240923 (Daily requests: 129/500)
# 2024-11-16 23:26:00,214 - INFO - Found 8 articles on page 0
# 2024-11-16 23:26:00,215 - INFO - Processing date: 20240924
# 2024-11-16 23:26:00,216 - INFO - Fetching page 0 for date 20240924 (Daily requests: 130/500)
# 2024-11-16 23:26:12,272 - INFO - Found 10 articles on page 0
# 2024-11-16 23:26:12,273 - INFO - Fetching page 1 for date 20240924 (Daily requests: 131/500)
# 2024-11-16 23:26:24,168 - INFO - Found 3 articles on page 1
# 2024-11-16 23:26:24,168 - INFO - Processing date: 20240925
# 2024-11-16 23:26:24,169 - INFO - Fetching page 0 for date 20240925 (Daily requests: 132/500)
# 2024-11-16 23:26:36,161 - INFO - Found 10 articles on page 0
# 2024-11-16 23:26:36,162 - INFO - Fetching page 1 for date 20240925 (Daily requests: 133/500)
# 2024-11-16 23:26:48,152 - INFO - Found 2 articles on page 1
# 2024-11-16 23:26:48,153 - INFO - Processing date: 20240926
# 2024-11-16 23:26:48,154 - INFO - Fetching page 0 for date 20240926 (Daily requests: 134/500)
# 2024-11-16 23:27:00,170 - INFO - Found 6 articles on page 0
# 2024-11-16 23:27:00,171 - INFO - Processing date: 20240927
# 2024-11-16 23:27:00,172 - INFO - Fetching page 0 for date 20240927 (Daily requests: 135/500)
# 2024-11-16 23:27:12,161 - INFO - Found 7 articles on page 0
# 2024-11-16 23:27:12,162 - INFO - Processing date: 20240928
# 2024-11-16 23:27:12,163 - INFO - Fetching page 0 for date 20240928 (Daily requests: 136/500)
# 2024-11-16 23:27:24,290 - INFO - Found 10 articles on page 0
# 2024-11-16 23:27:24,291 - INFO - Fetching page 1 for date 20240928 (Daily requests: 137/500)
# 2024-11-16 23:27:36,179 - INFO - Found 1 articles on page 1
# 2024-11-16 23:27:36,180 - INFO - Processing date: 20240929
# 2024-11-16 23:27:36,181 - INFO - Fetching page 0 for date 20240929 (Daily requests: 138/500)
# 2024-11-16 23:27:48,307 - INFO - Found 7 articles on page 0
# 2024-11-16 23:27:48,308 - INFO - Processing date: 20240930
# 2024-11-16 23:27:48,309 - INFO - Fetching page 0 for date 20240930 (Daily requests: 139/500)
# 2024-11-16 23:28:00,253 - INFO - Found 10 articles on page 0
# 2024-11-16 23:28:00,254 - INFO - Fetching page 1 for date 20240930 (Daily requests: 140/500)
# 2024-11-16 23:28:12,323 - INFO - Found 1 articles on page 1
# 2024-11-16 23:28:12,330 - INFO - Saved 215 articles for 2024-09 to Raw Data/NYT_Articles_2024_09.csv
# 2024-11-16 23:28:12,331 - INFO - Processing date: 20241001
# 2024-11-16 23:28:12,331 - INFO - Fetching page 0 for date 20241001 (Daily requests: 141/500)
# 2024-11-16 23:28:24,286 - INFO - Found 10 articles on page 0
# 2024-11-16 23:28:24,287 - INFO - Fetching page 1 for date 20241001 (Daily requests: 142/500)
# 2024-11-16 23:28:36,209 - INFO - Found 1 articles on page 1
# 2024-11-16 23:28:36,210 - INFO - Processing date: 20241002
# 2024-11-16 23:28:36,211 - INFO - Fetching page 0 for date 20241002 (Daily requests: 143/500)
# 2024-11-16 23:28:48,336 - INFO - Found 10 articles on page 0
# 2024-11-16 23:28:48,337 - INFO - Fetching page 1 for date 20241002 (Daily requests: 144/500)
# 2024-11-16 23:29:00,253 - INFO - Found 3 articles on page 1
# 2024-11-16 23:29:00,254 - INFO - Processing date: 20241003
# 2024-11-16 23:29:00,254 - INFO - Fetching page 0 for date 20241003 (Daily requests: 145/500)
# 2024-11-16 23:29:12,278 - INFO - Found 5 articles on page 0
# 2024-11-16 23:29:12,279 - INFO - Processing date: 20241004
# 2024-11-16 23:29:12,280 - INFO - Fetching page 0 for date 20241004 (Daily requests: 146/500)
# 2024-11-16 23:29:24,331 - INFO - Found 10 articles on page 0
# 2024-11-16 23:29:24,331 - INFO - Fetching page 1 for date 20241004 (Daily requests: 147/500)
# 2024-11-16 23:29:36,429 - INFO - Found 3 articles on page 1
# 2024-11-16 23:29:36,430 - INFO - Processing date: 20241005
# 2024-11-16 23:29:36,431 - INFO - Fetching page 0 for date 20241005 (Daily requests: 148/500)
# 2024-11-16 23:29:48,314 - INFO - Found 8 articles on page 0
# 2024-11-16 23:29:48,315 - INFO - Processing date: 20241006
# 2024-11-16 23:29:48,316 - INFO - Fetching page 0 for date 20241006 (Daily requests: 149/500)
# 2024-11-16 23:30:00,336 - INFO - Found 9 articles on page 0
# 2024-11-16 23:30:00,337 - INFO - Processing date: 20241007
# 2024-11-16 23:30:00,338 - INFO - Fetching page 0 for date 20241007 (Daily requests: 150/500)
# 2024-11-16 23:30:12,334 - INFO - Found 10 articles on page 0
# 2024-11-16 23:30:12,335 - INFO - Fetching page 1 for date 20241007 (Daily requests: 151/500)
# 2024-11-16 23:30:24,419 - INFO - Found 10 articles on page 1
# 2024-11-16 23:30:24,420 - INFO - Fetching page 2 for date 20241007 (Daily requests: 152/500)
# 2024-11-16 23:30:36,402 - INFO - Found 10 articles on page 2
# 2024-11-16 23:30:36,403 - INFO - Fetching page 3 for date 20241007 (Daily requests: 153/500)
# 2024-11-16 23:30:48,309 - INFO - Found 3 articles on page 3
# 2024-11-16 23:30:48,314 - INFO - Saved 92 articles for 2024-10 to Raw Data/NYT_Articles_2024_10.csv
