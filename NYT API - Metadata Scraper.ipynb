# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
import json
import logging
from pathlib import Path
import calendar

class NYTArticleScraper:
    def __init__(self, api_key, query, start_date, end_date=None):
        """
        Initialize the NYT Article Scraper
        
        Parameters:
        api_key (str): NYT API key
        query (str): Search query
        start_date (str): Start date in YYYYMMDD format
        end_date (str): Optional end date in YYYYMMDD format
        """
        self.api_key = api_key
        self.base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"
        self.query = query
        self.start_date = start_date
        self.end_date = end_date or start_date
        self.daily_requests = 0
        self.last_request_time = None
        self.current_date = datetime.now().strftime('%Y%m%d')
        
        # Setup logging
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s',
            handlers=[
                logging.FileHandler('NYT Metadata/NYT_Scraper.log'),
                logging.StreamHandler()
            ]
        )
        self.logger = logging.getLogger(__name__)
        
    def wait_for_rate_limit(self):
        """Manage API rate limits"""
        # Check if we need to reset daily counter
        current_date = datetime.now().strftime('%Y%m%d')
        if current_date != self.current_date:
            self.daily_requests = 0
            self.current_date = current_date
        
        # Check daily limit
        if self.daily_requests >= 500:
            wait_time = (datetime.now() + timedelta(days=1)).replace(
                hour=0, minute=0, second=0, microsecond=0
            ) - datetime.now()
            self.logger.info(f"Daily limit reached. Waiting {wait_time.seconds} seconds until midnight...")
            time.sleep(wait_time.seconds + 1)
            self.daily_requests = 0
            self.current_date = datetime.now().strftime('%Y%m%d')
        
        # Handle per-minute rate limit
        if self.last_request_time is not None:
            elapsed = time.time() - self.last_request_time
            if elapsed < 12:
                time.sleep(12 - elapsed)
        
        self.last_request_time = time.time()
        self.daily_requests += 1
        
    def get_params(self, page, current_date):
        """Generate parameters for API request"""
        return {
            'q': self.query,
            'news_desk': 'World;Politics',
            'begin_date': current_date,
            'end_date': current_date,
            'type_of_material': 'News',
            'api-key': self.api_key,
            'page': page,
            'sort': 'oldest'
        }
    
    def process_article(self, article):
        """Process a single article and extract relevant information"""
        try:
            persons = [kw['value'] for kw in article['keywords'] if kw['name'] == 'persons']
            places = [kw['value'] for kw in article['keywords'] if kw['name'] == 'glocations']
            subjects = [kw['value'] for kw in article['keywords'] if kw['name'] == 'subject']
            organizations = [kw['value'] for kw in article['keywords'] if kw['name'] == 'organizations']
            
            return {
                'headline': article['headline']['main'],
                'publication_date': pd.to_datetime(article['pub_date']),
                'people_mentioned': '; '.join(persons),
                'places_mentioned': '; '.join(places),
                'subjects': '; '.join(subjects),
                'organizations': '; '.join(organizations),
                'url': article['web_url'],
                'abstract': article.get('abstract', ''),
                'word_count': article.get('word_count', 0),
            }
        except KeyError as e:
            self.logger.error(f"Error processing article: {e}")
            return None
    
    def get_month_range(self, date_str):
        """Get the start and end date for a month containing the given date"""
        date = datetime.strptime(date_str, '%Y%m%d')
        _, last_day = calendar.monthrange(date.year, date.month)
        month_start = date.replace(day=1).strftime('%Y%m%d')
        month_end = date.replace(day=last_day).strftime('%Y%m%d')
        return month_start, month_end
    
    def fetch_articles_for_date(self, current_date):
        """Fetch all articles for a specific date"""
        page = 0
        articles_for_date = []
        
        while True:
            try:
                self.logger.info(f"Fetching page {page} for date {current_date} (Daily requests: {self.daily_requests}/500)")
                self.wait_for_rate_limit()
                
                params = self.get_params(page, current_date)
                response = requests.get(self.base_url, params=params)
                response.raise_for_status()
                data = response.json()
                
                if 'response' not in data or not data['response']['docs']:
                    break
                    
                processed_articles = [
                    article for article in [
                        self.process_article(doc) 
                        for doc in data['response']['docs']
                    ] 
                    if article is not None
                ]
                
                articles_for_date.extend(processed_articles)
                self.logger.info(f"Found {len(processed_articles)} articles on page {page}")
                
                # Check if we've reached the last page
                if len(data['response']['docs']) < 10:
                    break
                    
                page += 1
                
            except requests.exceptions.RequestException as e:
                self.logger.error(f"API request failed for date {current_date}, page {page}: {e}")
                break
            except json.JSONDecodeError as e:
                self.logger.error(f"JSON parsing error for date {current_date}, page {page}: {e}")
                break
            
        return articles_for_date
    
    def fetch_articles_by_month(self):
        """Fetch articles month by month"""
        current_date = datetime.strptime(self.start_date, '%Y%m%d')
        end_date = datetime.strptime(self.end_date, '%Y%m%d')
        
        while current_date <= end_date:
            # Get month range
            month_start, month_end = self.get_month_range(current_date.strftime('%Y%m%d'))
            month_articles = []
            
            # Process each day in the month
            current_day = max(current_date, datetime.strptime(month_start, '%Y%m%d'))
            month_end_date = min(end_date, datetime.strptime(month_end, '%Y%m%d'))
            
            while current_day <= month_end_date:
                current_day_str = current_day.strftime('%Y%m%d')
                self.logger.info(f"Processing date: {current_day_str}")
                
                articles = self.fetch_articles_for_date(current_day_str)
                month_articles.extend(articles)
                
                # # Save progress after each day
                # if articles:
                #     progress_file = month_dir / f'NYT_Articles_{current_day_str}.csv'
                #     pd.DataFrame(articles).to_csv(progress_file, index=False)
                #     self.logger.info(f"Saved {len(articles)} articles for {current_day_str}")
                
                current_day += timedelta(days=1)
            
            # Save month's articles
            if month_articles:
                monthly_file = f'NYT Metadata/NYT_Articles_{current_date.strftime("%Y_%m")}.csv'
                df = pd.DataFrame(month_articles)
                df.to_csv(monthly_file, index=False)
                self.logger.info(f"Saved {len(month_articles)} articles for {current_date.strftime('%Y-%m')} to {monthly_file}")
            
            # Move to first day of next month
            current_date = (current_date.replace(day=28) + timedelta(days=4)).replace(day=1)

def main():
    # Configuration
    API_KEY = "RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb"
    QUERY = "Israel-Gaza War (2023-)"
    START_DATE = "20240507"
    END_DATE = "20241007"
    
    # Initialize and run scraper
    scraper = NYTArticleScraper(
        api_key=API_KEY,
        query=QUERY,
        start_date=START_DATE,
        end_date=END_DATE
    )
    
    scraper.fetch_articles_by_month()

if __name__ == "__main__":
    main()
# Out:
# 2024-11-03 15:37:11,922 - INFO - Processing date: 20240307
# 2024-11-03 15:37:11,925 - INFO - Fetching page 0 for date 20240307 (Daily requests: 0/500)
# 2024-11-03 15:37:12,640 - INFO - Found 10 articles on page 0
# 2024-11-03 15:37:12,641 - INFO - Fetching page 1 for date 20240307 (Daily requests: 1/500)
# 2024-11-03 15:37:24,339 - INFO - Processing date: 20240308
# 2024-11-03 15:37:24,341 - INFO - Fetching page 0 for date 20240308 (Daily requests: 2/500)
# 2024-11-03 15:37:36,560 - INFO - Found 10 articles on page 0
# 2024-11-03 15:37:36,561 - INFO - Fetching page 1 for date 20240308 (Daily requests: 3/500)
# 2024-11-03 15:37:48,448 - INFO - Found 5 articles on page 1
# 2024-11-03 16:05:24,957 - INFO - Fetching page 1 for date 20240529 (Daily requests: 142/500)
# 2024-11-03 16:05:36,916 - INFO - Found 4 articles on page 1
# 2024-11-03 16:05:36,920 - INFO - Processing date: 20240530
# 2024-11-03 16:05:36,921 - INFO - Fetching page 0 for date 20240530 (Daily requests: 143/500)
# 2024-11-03 16:05:48,751 - ERROR - API request failed for date 20240530, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240530&end_date=20240530&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:05:48,757 - INFO - Processing date: 20240531
# 2024-11-03 16:05:48,758 - INFO - Fetching page 0 for date 20240531 (Daily requests: 144/500)
# 2024-11-03 16:06:00,718 - ERROR - API request failed for date 20240531, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240531&end_date=20240531&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:06:00,741 - INFO - Saved 406 articles for 2024-05 to NYT Metadata/NYT_Articles_2024_05.csv
# 2024-11-03 16:06:00,742 - INFO - Processing date: 20240601
# 2024-11-03 16:06:00,744 - INFO - Fetching page 0 for date 20240601 (Daily requests: 145/500)
# 2024-11-03 16:06:12,752 - ERROR - API request failed for date 20240601, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240601&end_date=20240601&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:06:12,759 - INFO - Processing date: 20240602
# 2024-11-03 16:06:12,761 - INFO - Fetching page 0 for date 20240602 (Daily requests: 146/500)
# 2024-11-03 16:06:24,758 - ERROR - API request failed for date 20240602, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240602&end_date=20240602&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:06:24,766 - INFO - Processing date: 20240603
# 2024-11-03 16:06:24,767 - INFO - Fetching page 0 for date 20240603 (Daily requests: 147/500)
# 2024-11-03 16:06:36,752 - ERROR - API request failed for date 20240603, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240603&end_date=20240603&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:06:36,759 - INFO - Processing date: 20240604
# 2024-11-03 16:06:36,760 - INFO - Fetching page 0 for date 20240604 (Daily requests: 148/500)
# 2024-11-03 16:06:48,972 - ERROR - API request failed for date 20240604, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240604&end_date=20240604&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:06:48,978 - INFO - Processing date: 20240605
# 2024-11-03 16:06:48,979 - INFO - Fetching page 0 for date 20240605 (Daily requests: 149/500)
# 2024-11-03 16:07:00,772 - ERROR - API request failed for date 20240605, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240605&end_date=20240605&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:07:00,780 - INFO - Processing date: 20240606
# 2024-11-03 16:07:00,781 - INFO - Fetching page 0 for date 20240606 (Daily requests: 150/500)
# 2024-11-03 16:07:12,769 - ERROR - API request failed for date 20240606, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240606&end_date=20240606&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:07:12,775 - INFO - Processing date: 20240607
# 2024-11-03 16:07:12,776 - INFO - Fetching page 0 for date 20240607 (Daily requests: 151/500)
# 2024-11-03 16:07:24,778 - ERROR - API request failed for date 20240607, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240607&end_date=20240607&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:07:24,784 - INFO - Processing date: 20240608
# 2024-11-03 16:07:24,786 - INFO - Fetching page 0 for date 20240608 (Daily requests: 152/500)
# 2024-11-03 16:07:36,783 - ERROR - API request failed for date 20240608, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240608&end_date=20240608&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:07:36,791 - INFO - Processing date: 20240609
# 2024-11-03 16:07:36,792 - INFO - Fetching page 0 for date 20240609 (Daily requests: 153/500)
# 2024-11-03 16:07:48,749 - ERROR - API request failed for date 20240609, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240609&end_date=20240609&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:07:48,758 - INFO - Processing date: 20240610
# 2024-11-03 16:07:48,759 - INFO - Fetching page 0 for date 20240610 (Daily requests: 154/500)
# 2024-11-03 16:08:00,767 - ERROR - API request failed for date 20240610, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240610&end_date=20240610&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:08:00,775 - INFO - Processing date: 20240611
# 2024-11-03 16:08:00,776 - INFO - Fetching page 0 for date 20240611 (Daily requests: 155/500)
# 2024-11-03 16:08:12,765 - ERROR - API request failed for date 20240611, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240611&end_date=20240611&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:08:12,771 - INFO - Processing date: 20240612
# 2024-11-03 16:08:12,772 - INFO - Fetching page 0 for date 20240612 (Daily requests: 156/500)
# 2024-11-03 16:08:24,769 - ERROR - API request failed for date 20240612, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240612&end_date=20240612&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:08:24,775 - INFO - Processing date: 20240613
# 2024-11-03 16:08:24,776 - INFO - Fetching page 0 for date 20240613 (Daily requests: 157/500)
# 2024-11-03 16:08:36,809 - ERROR - API request failed for date 20240613, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240613&end_date=20240613&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:08:36,815 - INFO - Processing date: 20240614
# 2024-11-03 16:08:36,816 - INFO - Fetching page 0 for date 20240614 (Daily requests: 158/500)
# 2024-11-03 16:08:48,820 - ERROR - API request failed for date 20240614, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240614&end_date=20240614&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:08:48,826 - INFO - Processing date: 20240615
# 2024-11-03 16:08:48,827 - INFO - Fetching page 0 for date 20240615 (Daily requests: 159/500)
# 2024-11-03 16:09:00,795 - ERROR - API request failed for date 20240615, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240615&end_date=20240615&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:09:00,802 - INFO - Processing date: 20240616
# 2024-11-03 16:09:00,803 - INFO - Fetching page 0 for date 20240616 (Daily requests: 160/500)
# 2024-11-03 16:09:12,831 - ERROR - API request failed for date 20240616, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240616&end_date=20240616&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:09:12,837 - INFO - Processing date: 20240617
# 2024-11-03 16:09:12,838 - INFO - Fetching page 0 for date 20240617 (Daily requests: 161/500)
# 2024-11-03 16:09:24,781 - ERROR - API request failed for date 20240617, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240617&end_date=20240617&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:09:24,787 - INFO - Processing date: 20240618
# 2024-11-03 16:09:24,788 - INFO - Fetching page 0 for date 20240618 (Daily requests: 162/500)
# 2024-11-03 16:09:36,821 - ERROR - API request failed for date 20240618, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240618&end_date=20240618&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:09:36,837 - INFO - Processing date: 20240619
# 2024-11-03 16:09:36,838 - INFO - Fetching page 0 for date 20240619 (Daily requests: 163/500)
# 2024-11-03 16:09:48,746 - ERROR - API request failed for date 20240619, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240619&end_date=20240619&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:09:48,757 - INFO - Processing date: 20240620
# 2024-11-03 16:09:48,758 - INFO - Fetching page 0 for date 20240620 (Daily requests: 164/500)
# 2024-11-03 16:10:00,826 - ERROR - API request failed for date 20240620, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240620&end_date=20240620&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:10:00,834 - INFO - Processing date: 20240621
# 2024-11-03 16:10:00,836 - INFO - Fetching page 0 for date 20240621 (Daily requests: 165/500)
# 2024-11-03 16:10:12,798 - ERROR - API request failed for date 20240621, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240621&end_date=20240621&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:10:12,801 - INFO - Processing date: 20240622
# 2024-11-03 16:10:12,802 - INFO - Fetching page 0 for date 20240622 (Daily requests: 166/500)
# 2024-11-03 16:10:24,791 - ERROR - API request failed for date 20240622, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240622&end_date=20240622&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:10:24,797 - INFO - Processing date: 20240623
# 2024-11-03 16:10:24,798 - INFO - Fetching page 0 for date 20240623 (Daily requests: 167/500)
# 2024-11-03 16:10:37,930 - ERROR - API request failed for date 20240623, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240623&end_date=20240623&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:10:37,936 - INFO - Processing date: 20240624
# 2024-11-03 16:10:37,937 - INFO - Fetching page 0 for date 20240624 (Daily requests: 168/500)
# 2024-11-03 16:10:48,817 - ERROR - API request failed for date 20240624, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240624&end_date=20240624&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:10:48,826 - INFO - Processing date: 20240625
# 2024-11-03 16:10:48,827 - INFO - Fetching page 0 for date 20240625 (Daily requests: 169/500)
# 2024-11-03 16:11:00,825 - ERROR - API request failed for date 20240625, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240625&end_date=20240625&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:11:00,834 - INFO - Processing date: 20240626
# 2024-11-03 16:11:00,835 - INFO - Fetching page 0 for date 20240626 (Daily requests: 170/500)
# 2024-11-03 16:11:12,830 - ERROR - API request failed for date 20240626, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240626&end_date=20240626&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:11:12,833 - INFO - Processing date: 20240627
# 2024-11-03 16:11:12,833 - INFO - Fetching page 0 for date 20240627 (Daily requests: 171/500)
# 2024-11-03 16:11:24,906 - ERROR - API request failed for date 20240627, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240627&end_date=20240627&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:11:24,908 - INFO - Processing date: 20240628
# 2024-11-03 16:11:24,909 - INFO - Fetching page 0 for date 20240628 (Daily requests: 172/500)
# 2024-11-03 16:11:36,800 - ERROR - API request failed for date 20240628, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240628&end_date=20240628&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:11:36,807 - INFO - Processing date: 20240629
# 2024-11-03 16:11:36,809 - INFO - Fetching page 0 for date 20240629 (Daily requests: 173/500)
# 2024-11-03 16:11:49,212 - ERROR - API request failed for date 20240629, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240629&end_date=20240629&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:11:49,216 - INFO - Processing date: 20240630
# 2024-11-03 16:11:49,217 - INFO - Fetching page 0 for date 20240630 (Daily requests: 174/500)
# 2024-11-03 16:12:00,841 - ERROR - API request failed for date 20240630, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240630&end_date=20240630&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:12:00,848 - INFO - Processing date: 20240701
# 2024-11-03 16:12:00,850 - INFO - Fetching page 0 for date 20240701 (Daily requests: 175/500)
# 2024-11-03 16:12:12,847 - ERROR - API request failed for date 20240701, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240701&end_date=20240701&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:12:12,853 - INFO - Processing date: 20240702
# 2024-11-03 16:12:12,854 - INFO - Fetching page 0 for date 20240702 (Daily requests: 176/500)
# 2024-11-03 16:12:24,857 - ERROR - API request failed for date 20240702, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240702&end_date=20240702&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:12:24,863 - INFO - Processing date: 20240703
# 2024-11-03 16:12:24,864 - INFO - Fetching page 0 for date 20240703 (Daily requests: 177/500)
# 2024-11-03 16:12:36,804 - ERROR - API request failed for date 20240703, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240703&end_date=20240703&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:12:36,811 - INFO - Processing date: 20240704
# 2024-11-03 16:12:36,814 - INFO - Fetching page 0 for date 20240704 (Daily requests: 178/500)
# 2024-11-03 16:12:48,886 - ERROR - API request failed for date 20240704, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240704&end_date=20240704&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:12:48,894 - INFO - Processing date: 20240705
# 2024-11-03 16:12:48,895 - INFO - Fetching page 0 for date 20240705 (Daily requests: 179/500)
# 2024-11-03 16:13:00,831 - ERROR - API request failed for date 20240705, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240705&end_date=20240705&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:13:00,836 - INFO - Processing date: 20240706
# 2024-11-03 16:13:00,838 - INFO - Fetching page 0 for date 20240706 (Daily requests: 180/500)
# 2024-11-03 16:13:12,852 - ERROR - API request failed for date 20240706, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240706&end_date=20240706&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:13:12,857 - INFO - Processing date: 20240707
# 2024-11-03 16:13:12,859 - INFO - Fetching page 0 for date 20240707 (Daily requests: 181/500)
# 2024-11-03 16:13:24,825 - ERROR - API request failed for date 20240707, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240707&end_date=20240707&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:13:24,831 - INFO - Processing date: 20240708
# 2024-11-03 16:13:24,835 - INFO - Fetching page 0 for date 20240708 (Daily requests: 182/500)
# 2024-11-03 16:13:36,869 - ERROR - API request failed for date 20240708, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240708&end_date=20240708&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:13:36,872 - INFO - Processing date: 20240709
# 2024-11-03 16:13:36,873 - INFO - Fetching page 0 for date 20240709 (Daily requests: 183/500)
# 2024-11-03 16:13:48,858 - ERROR - API request failed for date 20240709, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240709&end_date=20240709&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:13:48,864 - INFO - Processing date: 20240710
# 2024-11-03 16:13:48,865 - INFO - Fetching page 0 for date 20240710 (Daily requests: 184/500)
# 2024-11-03 16:14:00,856 - ERROR - API request failed for date 20240710, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240710&end_date=20240710&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:14:00,860 - INFO - Processing date: 20240711
# ...
# 2024-11-03 16:20:13,007 - INFO - Processing date: 20240811
# 2024-11-03 16:20:13,008 - INFO - Fetching page 0 for date 20240811 (Daily requests: 216/500)
# 2024-11-03 16:20:25,024 - ERROR - API request failed for date 20240811, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240811&end_date=20240811&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:20:25,031 - INFO - Processing date: 20240812
# 2024-11-03 16:20:25,032 - INFO - Fetching page 0 for date 20240812 (Daily requests: 217/500)
# 2024-11-03 16:20:37,001 - ERROR - API request failed for date 20240812, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240812&end_date=20240812&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:20:37,008 - INFO - Processing date: 20240813
# 2024-11-03 16:20:37,009 - INFO - Fetching page 0 for date 20240813 (Daily requests: 218/500)
# 2024-11-03 16:20:49,074 - ERROR - API request failed for date 20240813, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240813&end_date=20240813&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:20:49,079 - INFO - Processing date: 20240814
# 2024-11-03 16:20:49,080 - INFO - Fetching page 0 for date 20240814 (Daily requests: 219/500)
# 2024-11-03 16:21:00,949 - ERROR - API request failed for date 20240814, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240814&end_date=20240814&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:21:00,955 - INFO - Processing date: 20240815
# 2024-11-03 16:21:00,956 - INFO - Fetching page 0 for date 20240815 (Daily requests: 220/500)
# 2024-11-03 16:21:12,951 - ERROR - API request failed for date 20240815, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240815&end_date=20240815&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:21:12,958 - INFO - Processing date: 20240816
# 2024-11-03 16:21:12,959 - INFO - Fetching page 0 for date 20240816 (Daily requests: 221/500)
# 2024-11-03 16:21:25,100 - ERROR - API request failed for date 20240816, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240816&end_date=20240816&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:21:25,108 - INFO - Processing date: 20240817
# 2024-11-03 16:21:25,110 - INFO - Fetching page 0 for date 20240817 (Daily requests: 222/500)
# 2024-11-03 16:21:37,001 - ERROR - API request failed for date 20240817, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240817&end_date=20240817&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:21:37,010 - INFO - Processing date: 20240818
# 2024-11-03 16:21:37,011 - INFO - Fetching page 0 for date 20240818 (Daily requests: 223/500)
# 2024-11-03 16:21:49,309 - ERROR - API request failed for date 20240818, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240818&end_date=20240818&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:21:49,314 - INFO - Processing date: 20240819
# 2024-11-03 16:21:49,317 - INFO - Fetching page 0 for date 20240819 (Daily requests: 224/500)
# 2024-11-03 16:22:01,031 - ERROR - API request failed for date 20240819, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240819&end_date=20240819&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:22:01,037 - INFO - Processing date: 20240820
# 2024-11-03 16:22:01,039 - INFO - Fetching page 0 for date 20240820 (Daily requests: 225/500)
# 2024-11-03 16:22:13,015 - ERROR - API request failed for date 20240820, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240820&end_date=20240820&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:22:13,021 - INFO - Processing date: 20240821
# 2024-11-03 16:22:13,022 - INFO - Fetching page 0 for date 20240821 (Daily requests: 226/500)
# 2024-11-03 16:22:24,982 - ERROR - API request failed for date 20240821, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240821&end_date=20240821&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:22:24,990 - INFO - Processing date: 20240822
# 2024-11-03 16:22:24,991 - INFO - Fetching page 0 for date 20240822 (Daily requests: 227/500)
# 2024-11-03 16:22:37,006 - ERROR - API request failed for date 20240822, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240822&end_date=20240822&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:22:37,011 - INFO - Processing date: 20240823
# 2024-11-03 16:22:37,012 - INFO - Fetching page 0 for date 20240823 (Daily requests: 228/500)
# 2024-11-03 16:22:48,952 - ERROR - API request failed for date 20240823, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240823&end_date=20240823&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:22:48,960 - INFO - Processing date: 20240824
# 2024-11-03 16:22:48,961 - INFO - Fetching page 0 for date 20240824 (Daily requests: 229/500)
# 2024-11-03 16:23:01,007 - ERROR - API request failed for date 20240824, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240824&end_date=20240824&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:23:01,012 - INFO - Processing date: 20240825
# 2024-11-03 16:23:01,014 - INFO - Fetching page 0 for date 20240825 (Daily requests: 230/500)
# 2024-11-03 16:23:12,975 - ERROR - API request failed for date 20240825, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240825&end_date=20240825&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:23:12,980 - INFO - Processing date: 20240826
# 2024-11-03 16:23:12,981 - INFO - Fetching page 0 for date 20240826 (Daily requests: 231/500)
# 2024-11-03 16:23:25,006 - ERROR - API request failed for date 20240826, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240826&end_date=20240826&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:23:25,010 - INFO - Processing date: 20240827
# 2024-11-03 16:23:25,011 - INFO - Fetching page 0 for date 20240827 (Daily requests: 232/500)
# 2024-11-03 16:23:37,077 - ERROR - API request failed for date 20240827, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240827&end_date=20240827&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:23:37,082 - INFO - Processing date: 20240828
# 2024-11-03 16:23:37,083 - INFO - Fetching page 0 for date 20240828 (Daily requests: 233/500)
# 2024-11-03 16:23:48,972 - ERROR - API request failed for date 20240828, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240828&end_date=20240828&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:23:48,980 - INFO - Processing date: 20240829
# 2024-11-03 16:23:48,981 - INFO - Fetching page 0 for date 20240829 (Daily requests: 234/500)
# 2024-11-03 16:24:01,002 - ERROR - API request failed for date 20240829, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240829&end_date=20240829&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:24:01,010 - INFO - Processing date: 20240830
# 2024-11-03 16:24:01,012 - INFO - Fetching page 0 for date 20240830 (Daily requests: 235/500)
# 2024-11-03 16:24:13,024 - ERROR - API request failed for date 20240830, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240830&end_date=20240830&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:24:13,030 - INFO - Processing date: 20240831
# 2024-11-03 16:24:13,032 - INFO - Fetching page 0 for date 20240831 (Daily requests: 236/500)
# 2024-11-03 16:24:25,039 - ERROR - API request failed for date 20240831, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240831&end_date=20240831&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:24:25,045 - INFO - Processing date: 20240901
# 2024-11-03 16:24:25,046 - INFO - Fetching page 0 for date 20240901 (Daily requests: 237/500)
# 2024-11-03 16:24:37,012 - ERROR - API request failed for date 20240901, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240901&end_date=20240901&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:24:37,017 - INFO - Processing date: 20240902
# 2024-11-03 16:24:37,019 - INFO - Fetching page 0 for date 20240902 (Daily requests: 238/500)
# 2024-11-03 16:24:49,040 - ERROR - API request failed for date 20240902, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240902&end_date=20240902&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:24:49,045 - INFO - Processing date: 20240903
# 2024-11-03 16:24:49,046 - INFO - Fetching page 0 for date 20240903 (Daily requests: 239/500)
# 2024-11-03 16:25:01,008 - ERROR - API request failed for date 20240903, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240903&end_date=20240903&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:25:01,014 - INFO - Processing date: 20240904
# 2024-11-03 16:25:01,015 - INFO - Fetching page 0 for date 20240904 (Daily requests: 240/500)
# 2024-11-03 16:25:13,016 - ERROR - API request failed for date 20240904, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240904&end_date=20240904&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:25:13,024 - INFO - Processing date: 20240905
# 2024-11-03 16:25:13,025 - INFO - Fetching page 0 for date 20240905 (Daily requests: 241/500)
# 2024-11-03 16:25:24,984 - ERROR - API request failed for date 20240905, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240905&end_date=20240905&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:25:24,991 - INFO - Processing date: 20240906
# 2024-11-03 16:25:24,992 - INFO - Fetching page 0 for date 20240906 (Daily requests: 242/500)
# 2024-11-03 16:25:37,028 - ERROR - API request failed for date 20240906, page 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Israel-Gaza+War+%282023-%29&news_desk=World%3BPolitics&begin_date=20240906&end_date=20240906&type_of_material=News&api-key=RvLloVIecCR4YHO3qYT7vg0ggVv3mOAb&page=0&sort=oldest
# 2024-11-03 16:25:37,033 - INFO - Processing date: 20240907
# 2024-11-03 16:25:37,034 - INFO - Fetching page 0 for date 20240907 (Daily requests: 243/500)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 213
#     210     scraper.fetch_articles_by_month()
#     212 if __name__ == "__main__":
# --> 213     main()
#
# Cell In[5], line 210, in main()
#     202 # Initialize and run scraper
#     203 scraper = NYTArticleScraper(
#     204     api_key=API_KEY,
#     205     query=QUERY,
#     206     start_date=START_DATE,
#     207     end_date=END_DATE
#     208 )
# --> 210 scraper.fetch_articles_by_month()
#
# Cell In[5], line 174, in NYTArticleScraper.fetch_articles_by_month(self)
#     171 current_day_str = current_day.strftime('%Y%m%d')
#     172 self.logger.info(f"Processing date: {current_day_str}")
# --> 174 articles = self.fetch_articles_for_date(current_day_str)
#     175 month_articles.extend(articles)
#     177 # # Save progress after each day
#     178 # if articles:
#     179 #     progress_file = month_dir / f'NYT_Articles_{current_day_str}.csv'
#     180 #     pd.DataFrame(articles).to_csv(progress_file, index=False)
#     181 #     self.logger.info(f"Saved {len(articles)} articles for {current_day_str}")
#
# Cell In[5], line 120, in NYTArticleScraper.fetch_articles_for_date(self, current_date)
#     118 try:
#     119     self.logger.info(f"Fetching page {page} for date {current_date} (Daily requests: {self.daily_requests}/500)")
# --> 120     self.wait_for_rate_limit()
#     122     params = self.get_params(page, current_date)
#     123     response = requests.get(self.base_url, params=params)
#
# Cell In[5], line 63, in NYTArticleScraper.wait_for_rate_limit(self)
#      61     elapsed = time.time() - self.last_request_time
#      62     if elapsed < 12:
# ---> 63         time.sleep(12 - elapsed)
#      65 self.last_request_time = time.time()
#      66 self.daily_requests += 1
#
# KeyboardInterrupt:
